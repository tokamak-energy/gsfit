# %% [markdown]
# **Description of failure**-- `psi_b` from the limter is very close to `psi_b` from the x-point.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_r = 80
n_z = 161
r = np.linspace(0.01, 1.0, n_r)
z = np.linspace(-1.0, 1.0, n_z)
[r_grid, z_grid] = np.meshgrid(r, z)
r_flat = r_grid.flatten()
z_flat = z_grid.flatten()

psi_b = -0.059069372604888676

xpt_r = 0.33894642418735055
xpt_z = -0.5713182906388565
xpt_psi_b = -0.0590836619459338

mag_r_previous = 0.5115792196972574
mag_z_previous = -0.007343976139471093
vessel_r = np.array([0.1705, 0.1705, 0.1705, 0.1705, 0.1705, 0.1705, 0.1705, 0.1705, 0.1705, 0.1705, 0.1705, 0.17637899, 0.20363089, 0.2318904, 0.25066569, 0.26116484, 0.28432368, 0.30748251, 0.33064134, 0.35380018, 0.37695901, 0.40011785, 0.42327668, 0.44254297, 0.40290427, 0.36326556, 0.35578454, 0.39399826, 0.43221198, 0.4704257, 0.50863942, 0.54685314, 0.58506686, 0.62070207, 0.65698245, 0.69002108, 0.70873944, 0.7275579, 0.74637635, 0.76519481, 0.78401327, 0.80283173, 0.82165018, 0.84046863, 0.83023864, 0.79462525, 0.75901186, 0.72339847, 0.68778508, 0.65217169, 0.61655829, 0.62990008, 0.63005809, 0.63005809, 0.63005809, 0.65574039, 0.69570538, 0.73567037, 0.77563535, 0.81560034, 0.85308777, 0.88459685, 0.89582174, 0.90628574, 0.91674974, 0.92721373, 0.93767773, 0.94814173, 0.95860572, 0.96906972, 0.97953372, 0.98721185, 0.98721185, 0.98721185, 0.98721185, 0.98721185, 0.98721185, 0.98721185, 0.98721185, 0.97953372, 0.96906972, 0.95860572, 0.94814173, 0.93767773, 0.92721373, 0.91674974, 0.90628574, 0.89582174, 0.88459685, 0.85308777, 0.81560034, 0.77563535, 0.73567037, 0.69570538, 0.65574039, 0.63005809, 0.63005809, 0.63005809, 0.62990008, 0.61655829, 0.65217169, 0.68778508, 0.72339847, 0.75901186, 0.79462525, 0.83023864, 0.84046863, 0.82165018, 0.80283173, 0.78401327, 0.76519481, 0.74637635, 0.7275579, 0.70873944, 0.69002108, 0.65698245, 0.62070207, 0.58506686, 0.54685314, 0.50863942, 0.4704257, 0.43221198, 0.39399826, 0.35578454, 0.36326556, 0.40290427, 0.44254297, 0.42327668, 0.40011785, 0.37695901, 0.35380018, 0.33064134, 0.30748251, 0.28432368, 0.26116484, 0.25066569, 0.2318904, 0.20363089, 0.17637899, 0.1705, 0.1705, 0.1705, 0.1705, 0.1705, 0.1705, 0.1705, 0.1705, 0.1705, 0.1705, 0.1705])
vessel_z = np.array([0.0, -0.039964989, -0.079929977, -0.11989497, -0.15985995, -0.19982494, -0.23978993, -0.27975492, -0.31971991, -0.3596849, -0.39964989, -0.42239189, -0.42163089, -0.4498904, -0.48265925, -0.52045109, -0.55302207, -0.58559305, -0.61816403, -0.65073501, -0.68330599, -0.71587697, -0.74844795, -0.7793159, -0.78441231, -0.78950871, -0.79733318, -0.80903412, -0.82073506, -0.83243599, -0.84413693, -0.85583787, -0.86753881, -0.88364274, -0.89874344, -0.89832011, -0.86300975, -0.82775261, -0.79249547, -0.75723832, -0.72198118, -0.68672404, -0.6514669, -0.61620976, -0.60167551, -0.61981075, -0.63794598, -0.65608121, -0.67421644, -0.69235168, -0.71048691, -0.69246874, -0.65259755, -0.61263256, -0.57266757, -0.55838488, -0.55838488, -0.55838488, -0.55838488, -0.55838488, -0.55931535, -0.52440767, -0.48738567, -0.44881489, -0.41024411, -0.37167333, -0.33310255, -0.29453177, -0.25596098, -0.2173902, -0.17881943, -0.13987746, -0.099912471, -0.059947483, -0.019982494, 0.019982494, 0.059947483, 0.099912471, 0.13987746, 0.17881943, 0.2173902, 0.25596098, 0.29453177, 0.33310255, 0.37167333, 0.41024411, 0.44881489, 0.48738567, 0.52440767, 0.54931535, 0.54838488, 0.54838488, 0.54838488, 0.54838488, 0.54838488, 0.56266757, 0.60263256, 0.64259755, 0.68246874, 0.70048691, 0.68235168, 0.66421644, 0.64608121, 0.62794598, 0.60981075, 0.59167551, 0.61620976, 0.6514669, 0.68672404, 0.72198118, 0.75723832, 0.79249547, 0.82775261, 0.86300975, 0.89832011, 0.89874344, 0.88364274, 0.86753881, 0.85583787, 0.84413693, 0.83243599, 0.82073506, 0.80903412, 0.79733318, 0.78950871, 0.78441231, 0.7793159, 0.74844795, 0.71587697, 0.68330599, 0.65073501, 0.61816403, 0.58559305, 0.55302207, 0.52045109, 0.48265925, 0.4498904, 0.42163089, 0.42239189, 0.39964989, 0.3596849, 0.31971991, 0.27975492, 0.23978993, 0.19982494, 0.15985995, 0.11989497, 0.079929977, 0.039964989, -0.0])

psi2d = np.loadtxt('psi2d.txt')
psi_2d = psi2d.reshape((161, 80))

mask_2d = np.loadtxt('mask_2d.txt').reshape((161, 80))

# %%
from operator import index


plt.figure(figsize=(10, 8))
plt.axis('equal')
plt.contour(r, z, psi_2d)
plt.plot(r_flat, z_flat, 'k.', markersize=1)
plt.plot(vessel_r, vessel_z, color='red', marker='o', linewidth=2)
plt.contour(r, z, psi_2d, levels=[psi_b], colors='b', linewidths=2)
plt.contour(r, z, psi_2d, levels=[xpt_psi_b], colors='r', linewidths=2)
plt.xlim(0, 0.5)
plt.ylim(-0.7, -0.5)
plt.plot(xpt_r, xpt_z, color='red', marker='x', markersize=10)

index_inside_plasma = mask_2d == 1
index_outside_plasma = mask_2d == 0

plt.plot(r_grid[index_inside_plasma], z_grid[index_inside_plasma], color='green', marker='o', linestyle='none', markersize=2)
plt.plot(r_grid[index_outside_plasma], z_grid[index_outside_plasma], color='black', marker='o', linestyle='none', markersize=0.5)
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
