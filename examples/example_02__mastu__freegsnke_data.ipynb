# %% [markdown]
# # **Example 02**: GSFit reconstructs MAST-U from synthetic magnetic diagnostics generated by FreeGSNKE
# The equilibrium reconstruction problem is 'ill posed', there are a finite number of sensors.
# There is no formal guarantee that the equilibrium reconstruction will be the same as the equilibrium used to create the measurements.
# There could even be multiple solutions that equally match the magnetic measurements.

# %%
import os
from datetime import datetime

import gsfit_rs
import matplotlib.pyplot as plt
import numpy as np
import shapely
from gsfit import Gsfit
from scipy.constants import mu_0

# %%
# %matplotlib widget
# %matplotlib inline

# %% [markdown]
# # 1. FreeGSNKE synthetic equilibrium data
# We start by constructing a FreeGSNKE equilibrium, including MAST-U's magnetic probes.

# %%
# build the machine
from freegsnke import build_machine

# include the paths to data files
freegsnke_tokamak = build_machine.tokamak(
    active_coils_path=os.path.expanduser("~/github/freegsnke/machine_configs/MAST-U/MAST-U_like_active_coils.pickle"),
    passive_coils_path=os.path.expanduser("~/github/freegsnke/machine_configs/MAST-U/MAST-U_like_passive_coils.pickle"),
    limiter_path=os.path.expanduser("~/github/freegsnke/machine_configs/MAST-U/MAST-U_like_limiter.pickle"),
    wall_path=os.path.expanduser("~/github/freegsnke/machine_configs/MAST-U/MAST-U_like_wall.pickle"),
    magnetic_probe_path=os.path.expanduser("~/github/freegsnke/machine_configs/MAST-U/MAST-U_like_magnetic_probes.pickle"),
)

# initialise the equilibrium
from freegsnke import equilibrium_update

freegsnke_eq = equilibrium_update.Equilibrium(
    tokamak=freegsnke_tokamak,
    Rmin=0.1,
    Rmax=2.0,
    Zmin=-2.2,
    Zmax=2.2,
    nx=65,
    ny=129,
)

# initialise the profiles
from freegsnke.jtor_update import ConstrainPaxisIp

profiles = ConstrainPaxisIp(
    eq=freegsnke_eq,  # equilibrium object
    paxis=8e3,  # pressure at axis [pascal]
    Ip=600.0e3,  # plasma current
    fvac=0.5,  # fvac = rB_{tor}
    alpha_m=1.8,  # profile function parameter
    alpha_n=1.2,  # profile function parameter
)

# load the nonlinear solver
from freegsnke import GSstaticsolver

GSStaticSolver = GSstaticsolver.NKGSsolver(freegsnke_eq)

# set the coil currents
import pickle

with open(os.path.expanduser("~/github/freegsnke/examples/data/simple_diverted_currents_PaxisIp.pk"), "rb") as f:
    current_values = pickle.load(f)
for key in current_values.keys():
    freegsnke_eq.tokamak[key].current = current_values[key]

# carry out the forward solve to find the equilibrium
GSStaticSolver.solve(eq=freegsnke_eq, profiles=profiles, constrain=None, target_relative_tolerance=1e-9)

# updates the plasma_psi
freegsnke_eq._updatePlasmaPsi(freegsnke_eq.plasma_psi)

# Initialise the sensors (calculate the Greens tables)
freegsnke_tokamak.probes.initialise_setup(freegsnke_eq)

# plot the resulting equilbria
fig1, ax1 = plt.subplots(1, 1, figsize=(4, 8), dpi=80)
ax1.grid(True, which="both")
freegsnke_eq.plot(axis=ax1, show=False)
freegsnke_eq.tokamak.plot(axis=ax1, show=False)
ax1.set_xlim(0.1, 2.15)
ax1.set_ylim(-2.25, 2.25)
freegsnke_eq.tokamak.probes.plot(axis=ax1, show=False, floops=True, pickups=True, pickups_scale=0.05)
plt.tight_layout()
# Out:
# Active coils --> built from pickle file.
# Passive structures --> built from pickle file.
# Limiter --> built from pickle file.
# Wall --> built from pickle file.
# Magnetic probes --> built from pickle file.
# Resistance (R) and inductance (M) matrices --> built using actives (and passives if present).
# Tokamak built.
# Forward static solve SUCCESS. Tolerance 3.69e-10 (vs. requested 1.00e-09) reached in 26/100 iterations.

# %% [markdown]
# # 2. Equilibrium reconstruction with GSFit
# ## 2.1 GSFit, magnetic only reconstruction
# We shall now use the sensor values from FreeGSNKE as "measured" values for GSFit equilibrium reconstruction.
#
# Note, the `settings_path="mastu_with_synthetic_data_from_freegsnke"` specifies which directory to load the *.json settings from.
# The settings directory constains a list of magnetic probes, e.g. `sensor_weights_bp_probe.json` along with weights, expected values, and wheter to use the sensor in the reconstruction.

# %%
# Setup GSFit using the settings for MAST-U.
gsfit_controller = Gsfit(
    pulseNo=0,
    run_name="test",
    settings_path="mastu_with_synthetic_data_from_freegsnke",
    write_to_mds=False,
)

# GSFit is naturally a time-dependent code
time = np.array([0.0, 1.0])
freegsnke_eqs = [freegsnke_eq, freegsnke_eq]  # we could extend this example to include time-dependent equilibria

# Solve the equilibrium reconstruction using the FreeGSNKE equilibrium object as measurements
gsfit_controller.run(
    time=time,
    freegsnke_eqs=freegsnke_eqs,
)

# We can now access the results from the GSFit reconstruction
plasma = gsfit_controller.plasma
flux_loops = gsfit_controller.flux_loops
bp_probes = gsfit_controller.bp_probes
# Out:
# 2026-07-18 21:40:47  |  GSFIT  |  diagnostic_and_simulation_base.py:155  |  INFO  |  Loading settings from: "GSFIT_code_settings.json"
# 2026-07-18 21:40:47  |  GSFIT  |  diagnostic_and_simulation_base.py:155  |  INFO  |  Loading settings from: "passive_dof_regularisation.json"
# 2026-07-18 21:40:47  |  GSFIT  |  diagnostic_and_simulation_base.py:155  |  INFO  |  Loading settings from: "sensor_weights_bp_probe.json"
# 2026-07-18 21:40:47  |  GSFIT  |  diagnostic_and_simulation_base.py:155  |  INFO  |  Loading settings from: "sensor_weights_dialoop.json"
# 2026-07-18 21:40:47  |  GSFIT  |  diagnostic_and_simulation_base.py:155  |  INFO  |  Loading settings from: "sensor_weights_flux_loops.json"
# 2026-07-18 21:40:47  |  GSFIT  |  diagnostic_and_simulation_base.py:155  |  INFO  |  Loading settings from: "sensor_weights_isoflux.json"
# 2026-07-18 21:40:47  |  GSFIT  |  diagnostic_and_simulation_base.py:155  |  INFO  |  Loading settings from: "sensor_weights_pressure.json"
# 2026-07-18 21:40:47  |  GSFIT  |  diagnostic_and_simulation_base.py:155  |  INFO  |  Loading settings from: "sensor_weights_rogowski_coils.json"
# 2026-07-18 21:40:47  |  GSFIT  |  diagnostic_and_simulation_base.py:155  |  INFO  |  Loading settings from: "source_function_ff_prime.json"
# 2026-07-18 21:40:47  |  GSFIT  |  diagnostic_and_simulation_base.py:155  |  INFO  |  Loading settings from: "source_function_p_prime.json"
# 2026-07-18 21:40:47  |  GSFIT  |  gsfit.py:93                            |  INFO  |  Running Gsfit, for pulseNo=0
# 2026-07-18 21:40:47  |  GSFIT  |  gsfit.py:299                           |  INFO  |  `coils`  initialised;  0.78ms
# 2026-07-18 21:40:47  |  GSFIT  |  gsfit.py:304                           |  INFO  |  `bp_probes` initialised;  8.62ms
# 2026-07-18 21:40:47  |  GSFIT  |  gsfit.py:309                           |  INFO  |  `flux_loops` initialised;  3.20ms
# 2026-07-18 21:40:47  |  GSFIT  |  gsfit.py:314                           |  INFO  |  `rogowski_coils` initialised;  0.05ms
# 2026-07-18 21:40:47  |  GSFIT  |  gsfit.py:319                           |  INFO  |  `passives` initialised;  0.00ms
# 2026-07-18 21:40:47  |  GSFIT  |  gsfit.py:324                           |  INFO  |  `plasma` initialised;  32.60ms
# 2026-07-18 21:40:47  |  GSFIT  |  gsfit.py:330                           |  INFO  |  `isoflux` initialised;  0.01ms
# 2026-07-18 21:40:47  |  GSFIT  |  gsfit.py:335                           |  INFO  |  `isoflux_boundary` initialised;  0.01ms
# 2026-07-18 21:40:47  |  GSFIT  |  gsfit.py:340                           |  INFO  |  `pressure_sensors` initialised;  0.00ms
# 2026-07-18 21:40:47  |  GSFIT  |  gsfit.py:350                           |  INFO  |  `stationary_point` initialised;  0.01ms
# 2026-07-18 21:40:47  |  GSFIT  |  gsfit.py:355                           |  INFO  |  `dialoop` initialised;  0.00ms
# 2026-07-18 21:40:48  |  GSFIT  |  gsfit.py:252                           |  INFO  |  Finished Greens with coils;  1,145.59ms
# 2026-07-18 21:40:48  |  GSFIT  |  gsfit.py:265                           |  INFO  |  Finished Greens with passives;  0.83ms
# 2026-07-18 21:40:49  |  GSFIT  |  gsfit.py:277                           |  INFO  |  Finished Greens with plasma;  1,337.43ms
# 2026-07-18 21:40:49  |  GSFIT  |  gsfit.py:198                           |  INFO  |  About to call: `gsfit_rs.solve_grad_shafranov`
# solve_grad_shafranov starting
# 2026-07-18 21:40:53  |  GSFIT  |  gsfit.py:222                           |  INFO  |  Finished: `gsfit_rs.solve_inverse_problem` time = 4,172.14ms
# time= 500.0ms;  solution_found=true;  gs_error=0.000000497666414355622;  n_iter=8
# equilibrium_post_processor: starting
# 2026-07-18 21:40:53  |  GSFIT  |  gsfit.py:131                           |  INFO  |  pulseNo = 0 pulseNo_write = 0 run_name = TEST

# %%
# To see what is inside the `plasma` object, we can print the keys (this works the same for other objects like `flux_loops` and `bp_probes`):
plasma.print_keys()

# To access data from the `plasma` object, we can use `get_***` methods, such as `get_array1`, `get_array2`, etc.
# Rust is a strictly typed language; this is why we need to specify the type of data we want to extract.
# For example, let's extract `time` and `Ip` from the plasma object:
gsfit_time = plasma.get_array1(["time"])
gsfit_Ip = plasma.get_array1(["global", "ip"])
# Out:
# ["boundary", "bounding", "r"]                    -> Array1<f64>;  shape=(1)
# ["boundary", "bounding", "z"]                    -> Array1<f64>;  shape=(1)
# ["boundary", "elongation"]                       -> Array1<f64>;  shape=(1)
# ["boundary", "geometric_axis", "r"]              -> Array1<f64>;  shape=(1)
# ["boundary", "geometric_axis", "z"]              -> Array1<f64>;  shape=(1)
# ["boundary", "minor_radius"]                     -> Array1<f64>;  shape=(1)
# ["boundary", "outline", "n"]                     -> Vec<usize>;  shape=1
# ["boundary", "outline", "r"]                     -> Array2<f64>;  shape=(1, 200)
# ["boundary", "outline", "z"]                     -> Array2<f64>;  shape=(1, 200)
# ["boundary", "psi"]                              -> Array1<f64>;  shape=(1)
# ["boundary", "squareness_lower_inner"]           -> Array1<f64>;  shape=(1)
# ["boundary", "squareness_lower_outer"]           -> Array1<f64>;  shape=(1)
# ["boundary", "squareness_upper_inner"]           -> Array1<f64>;  shape=(1)
# ["boundary", "squareness_upper_outer"]           -> Array1<f64>;  shape=(1)
# ["boundary", "triangularity"]                    -> Array1<f64>;  shape=(1)
# ["boundary", "triangularity_lower"]              -> Array1<f64>;  shape=(1)
# ["boundary", "triangularity_upper"]              -> Array1<f64>;  shape=(1)
# ["global", "area"]                               -> Array1<f64>;  shape=(1)
# ["global", "beta_n"]                             -> Array1<f64>;  shape=(1)
# ["global", "beta_p_1"]                           -> Array1<f64>;  shape=(1)
# ["global", "beta_p_2"]                           -> Array1<f64>;  shape=(1)
# ["global", "beta_p_3"]                           -> Array1<f64>;  shape=(1)
# ["global", "beta_t"]                             -> Array1<f64>;  shape=(1)
# ["global", "bt_vac_at_r_geo"]                    -> Array1<f64>;  shape=(1)
# ["global", "chi_mag"]                            -> Array1<f64>;  shape=(1)
# ["global", "delta_z"]                            -> Array1<f64>;  shape=(1)
# ["global", "gs_error"]                           -> Array1<f64>;  shape=(1)
# ["global", "i_rod"]                              -> Array1<f64>;  shape=(1)
# ["global", "ip"]                                 -> Array1<f64>;  shape=(1)
# ["global", "li_1"]                               -> Array1<f64>;  shape=(1)
# ["global", "li_2"]                               -> Array1<f64>;  shape=(1)
# ["global", "li_3"]                               -> Array1<f64>;  shape=(1)
# ["global", "n_iter"]                             -> Vec<usize>;  shape=1
# ["global", "p"]                                  -> Array1<f64>;  shape=(1)
# ["global", "phi_dia"]                            -> Array1<f64>;  shape=(1)
# ["global", "psi_a"]                              -> Array1<f64>;  shape=(1)
# ["global", "q_95"]                               -> Array1<f64>;  shape=(1)
# ["global", "q_axis"]                             -> Array1<f64>;  shape=(1)
# ["global", "r_cur"]                              -> Array1<f64>;  shape=(1)
# ["global", "r_mag"]                              -> Array1<f64>;  shape=(1)
# ["global", "v_loop"]                             -> Array1<f64>;  shape=(1)
# ["global", "volume"]                             -> Array1<f64>;  shape=(1)
# ["global", "w_mhd"]                              -> Array1<f64>;  shape=(1)
# ["global", "xpt_diverted"]                       -> Vec<bool>;  shape=1
# ["global", "z_cur"]                              -> Array1<f64>;  shape=(1)
# ["global", "z_mag"]                              -> Array1<f64>;  shape=(1)
# ["greens", "grid_grid", "br"]                    -> Array2<f64>;  shape=(8385, 65)
# ["greens", "grid_grid", "bz"]                    -> Array2<f64>;  shape=(8385, 65)
# ["greens", "grid_grid", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(8385, 65)
# ["greens", "grid_grid", "d_br_d_z"]              -> Array2<f64>;  shape=(8385, 65)
# ["greens", "grid_grid", "d_bz_d_z"]              -> Array2<f64>;  shape=(8385, 65)
# ["greens", "grid_grid", "psi"]                   -> Array2<f64>;  shape=(8385, 65)
# ["greens", "pf", "D11", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D11", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D11", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D11", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D11", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D11", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D11", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D12", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D12", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D12", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D12", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D12", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D12", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D12", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D21", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D21", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D21", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D21", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D21", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D21", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D21", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D22", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D22", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D22", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D22", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D22", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D22", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D22", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D31", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D31", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D31", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D31", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D31", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D31", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D31", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D32", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D32", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D32", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D32", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D32", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D32", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D32", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D51", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D51", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D51", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D51", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D51", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D51", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D51", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D52", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D52", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D52", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D52", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D52", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D52", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D52", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D61", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D61", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D61", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D61", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D61", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D61", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D61", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D62", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D62", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D62", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D62", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D62", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D62", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D62", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D71", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D71", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D71", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D71", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D71", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D71", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D71", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D72", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D72", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D72", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D72", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D72", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D72", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "D72", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp1", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp1", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp1", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp1", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp1", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp1", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp1", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp2", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp2", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp2", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp2", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp2", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp2", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Dp2", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P41", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P41", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P41", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P41", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P41", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P41", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P41", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P42", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P42", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P42", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P42", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P42", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P42", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P42", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P51", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P51", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P51", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P51", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P51", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P51", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P51", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P52", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P52", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P52", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P52", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P52", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P52", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P52", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P61", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P61", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P61", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P61", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P61", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P61", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P61", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P62", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P62", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P62", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P62", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P62", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P62", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "P62", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX1", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX1", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX1", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX1", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX1", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX1", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX1", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX2", "br"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX2", "bz"]                    -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX2", "d2_psi_d_r2"]           -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX2", "d_br_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX2", "d_bz_d_z"]              -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX2", "d_psi_d_z"]             -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "PX2", "psi"]                   -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Solenoid", "br"]               -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Solenoid", "bz"]               -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Solenoid", "d2_psi_d_r2"]      -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Solenoid", "d_br_d_z"]         -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Solenoid", "d_bz_d_z"]         -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Solenoid", "d_psi_d_z"]        -> Array2<f64>;  shape=(129, 65)
# ["greens", "pf", "Solenoid", "psi"]              -> Array2<f64>;  shape=(129, 65)
# ["grid", "d_area"]                               -> f64;  value=0.001020507812499995
# ["grid", "flat", "r"]                            -> Array1<f64>;  shape=(8385)
# ["grid", "flat", "z"]                            -> Array1<f64>;  shape=(8385)
# ["grid", "mesh", "r"]                            -> Array2<f64>;  shape=(129, 65)
# ["grid", "mesh", "z"]                            -> Array2<f64>;  shape=(129, 65)
# ["grid", "n_r"]                                  -> usize;  value=65
# ["grid", "n_z"]                                  -> usize;  value=129
# ["grid", "r"]                                    -> Array1<f64>;  shape=(65)
# ["grid", "z"]                                    -> Array1<f64>;  shape=(129)
# ["limiter", "limit_pts", "r"]                    -> Array1<f64>;  shape=(47)
# ["limiter", "limit_pts", "z"]                    -> Array1<f64>;  shape=(47)
# ["profiles_1d", "psi_norm", "area"]              -> Array2<f64>;  shape=(1, 100)
# ["profiles_1d", "psi_norm", "area_prime"]        -> Array2<f64>;  shape=(1, 100)
# ["profiles_1d", "psi_norm", "f"]                 -> Array2<f64>;  shape=(1, 100)
# ["profiles_1d", "psi_norm", "ff_prime"]          -> Array2<f64>;  shape=(1, 100)
# ["profiles_1d", "psi_norm", "flux_tor"]          -> Array2<f64>;  shape=(1, 100)
# ["profiles_1d", "psi_norm", "p"]                 -> Array2<f64>;  shape=(1, 100)
# ["profiles_1d", "psi_norm", "p_prime"]           -> Array2<f64>;  shape=(1, 100)
# ["profiles_1d", "psi_norm", "psi"]               -> Array2<f64>;  shape=(1, 100)
# ["profiles_1d", "psi_norm", "psi_norm"]          -> Array1<f64>;  shape=(100)
# ["profiles_1d", "psi_norm", "q"]                 -> Array2<f64>;  shape=(1, 100)
# ["profiles_1d", "psi_norm", "rho_pol"]           -> Array2<f64>;  shape=(1, 100)
# ["profiles_1d", "psi_norm", "rho_tor"]           -> Array2<f64>;  shape=(1, 100)
# ["profiles_1d", "psi_norm", "vol"]               -> Array2<f64>;  shape=(1, 100)
# ["profiles_1d", "psi_norm", "vol_prime"]         -> Array2<f64>;  shape=(1, 100)
# ["profiles_1d", "r_midplane", "p"]               -> Array2<f64>;  shape=(1, 65)
# ["profiles_1d", "r_midplane", "r"]               -> Array1<f64>;  shape=(65)
# ["profiles_2d", "r_z", "br"]                     -> Array3<f64>;  shape=(1, 129, 65)
# ["profiles_2d", "r_z", "bt"]                     -> Array3<f64>;  shape=(1, 129, 65)
# ["profiles_2d", "r_z", "bz"]                     -> Array3<f64>;  shape=(1, 129, 65)
# ["profiles_2d", "r_z", "d_bz_d_z"]               -> Array3<f64>;  shape=(1, 129, 65)
# ["profiles_2d", "r_z", "j"]                      -> Array3<f64>;  shape=(1, 129, 65)
# ["profiles_2d", "r_z", "mask"]                   -> Array3<f64>;  shape=(1, 129, 65)
# ["profiles_2d", "r_z", "p"]                      -> Array3<f64>;  shape=(1, 129, 65)
# ["profiles_2d", "r_z", "psi"]                    -> Array3<f64>;  shape=(1, 129, 65)
# ["profiles_2d", "r_z", "psi_norm"]               -> Array3<f64>;  shape=(1, 129, 65)
# ["sol", "hfs", "contour", "n"]                   -> Vec<usize>;  shape=1
# ["sol", "hfs", "contour", "r"]                   -> Array2<f64>;  shape=(1, 14)
# ["sol", "hfs", "contour", "z"]                   -> Array2<f64>;  shape=(1, 14)
# ["sol", "hfs", "strike_point", "r"]              -> Array1<f64>;  shape=(1)
# ["sol", "hfs", "strike_point", "z"]              -> Array1<f64>;  shape=(1)
# ["sol", "lfs", "contour", "n"]                   -> Vec<usize>;  shape=1
# ["sol", "lfs", "contour", "r"]                   -> Array2<f64>;  shape=(1, 19)
# ["sol", "lfs", "contour", "z"]                   -> Array2<f64>;  shape=(1, 19)
# ["sol", "lfs", "strike_point", "r"]              -> Array1<f64>;  shape=(1)
# ["sol", "lfs", "strike_point", "z"]              -> Array1<f64>;  shape=(1)
# ["source_functions", "ff_prime", "coefficients"] -> Array2<f64>;  shape=(1, 2)
# ["source_functions", "p_prime", "coefficients"]  -> Array2<f64>;  shape=(1, 2)
# ["time"]                                         -> Array1<f64>;  shape=(1)
# ["vessel", "r"]                                  -> Array1<f64>;  shape=(47)
# ["vessel", "z"]                                  -> Array1<f64>;  shape=(47)
# ["xpoints", "lower", "r"]                        -> Array1<f64>;  shape=(1)
# ["xpoints", "lower", "z"]                        -> Array1<f64>;  shape=(1)
# ["xpoints", "upper", "r"]                        -> Array1<f64>;  shape=(1)
# ["xpoints", "upper", "z"]                        -> Array1<f64>;  shape=(1)

# %% [markdown]
# ## 2.1 Comparison between FreeGSNKE and GSFit equilibrium reconstruction (magnetic only)

# %%
def plot_2d_equilibrium(freegsnke_eq, gsfit_controller):
    # Get results out of GSFit
    plasma = gsfit_controller.plasma
    i_time = 0
    gsfit_r = plasma.get_array1(["grid", "r"])
    gsfit_z = plasma.get_array1(["grid", "z"])
    gsfit_psi = plasma.get_array3(["profiles_2d", "r_z", "psi"])[i_time, :, :]
    gsfit_rbnd = plasma.get_array2(["boundary", "outline", "r"])[i_time, :]
    gsfit_zbnd = plasma.get_array2(["boundary", "outline", "z"])[i_time, :]
    gsfit_nbnd = plasma.get_vec_usize(["boundary", "outline", "n"])[i_time]

    # Get results out of FreeGSNKE
    freegsnke_r = freegsnke_eq.R
    freegsnke_z = freegsnke_eq.Z
    freegsnke_psi = freegsnke_eq.psi() * (2.0 * np.pi)  # convert from "weber/(2*pi)" to "weber"
    freegsnke_psi_b = freegsnke_eq.psi_bndry * (2.0 * np.pi)

    # We will plot the same psi values for both FreeGSNKE and GSFit
    psi_range = np.linspace(np.min(freegsnke_psi), np.max(freegsnke_psi), 25)

    fig, ax = plt.subplots(1, 2, figsize=(12, 8), dpi=80)
    for i_axis in range(2):
        ax[i_axis].grid(True, which="both")
        ax[i_axis].set_aspect("equal")
        ax[i_axis].contour(
            freegsnke_r,
            freegsnke_z,
            freegsnke_psi,
            levels=psi_range,
            colors="blue",
            linewidths=0.5,
            linestyles="solid",
        )
        ax[i_axis].contour(
            freegsnke_r,
            freegsnke_z,
            freegsnke_psi,
            levels=[freegsnke_psi_b],
            colors="blue",
            linewidths=1.0,
            linestyles="solid",
        )
        ax[i_axis].contour(
            gsfit_r,
            gsfit_z,
            gsfit_psi,
            levels=psi_range,
            colors="red",
            linewidths=0.5,
            linestyles="dashed",
        )
        ax[i_axis].plot(
            gsfit_rbnd[0:gsfit_nbnd],
            gsfit_zbnd[0:gsfit_nbnd],
            color="red",
            linewidth=1.0,
            linestyle="dashed",
        )
        ax[i_axis].set_xlabel("R [m]")
        ax[i_axis].set_ylabel("Z [m]")
        ax[i_axis].plot([], [], label="FreeGSNKE", color="blue")
        ax[i_axis].plot([], [], label="GSFit", linestyle="dashed", color="red")
        ax[i_axis].legend()

    ax[1].set_xlim(0.3, 0.8)
    ax[1].set_ylim(0.75, 1.25)
    [r_mesh, z_mesh] = np.meshgrid(freegsnke_eq.R_1D, freegsnke_eq.Z_1D)
    ax[1].plot(r_mesh.flatten(), z_mesh.flatten(), "o", color="black", markersize=0.75)
    ax[1].set_title("Zoomed in comparison near the\n upper X-point; showing (R, Z) grid points")


plot_2d_equilibrium(freegsnke_eq, gsfit_controller)

# %% [markdown]
# In the figure above we compare the poloidal flux from FreeGSNKE and GSFit (note the contours have the same value).
# We see excellent agreement in the vacuum, but some discrepancy in the core.
# This is to be expected, as we have not supplied any internal measurements and this is a magnetics only equilibrium reconstruction.

# %%
# Compare flux_loops measured vs calculated value
i_time = 0
flux_loops_names = flux_loops.keys()
flux_loops_measured = flux_loops.get_array2(["*", "psi", "measured", "value"])[i_time, :]
flux_loops_calculated = flux_loops.get_array2(["*", "psi", "calculated", "value"])[i_time, :]

fig, ax = plt.subplots(1, 1, figsize=(12, 4), dpi=110)
ax.plot(
    flux_loops_names,
    flux_loops_measured,
    label="Measured (FreeGSNKE)",
    color="blue",
    linewidth=0.5,
    marker="+",
    markersize=2.5,
)
ax.plot(
    flux_loops_names,
    flux_loops_calculated,
    label="Calculated (GSFit)",
    color="red",
    linestyle="dashed",
    linewidth=0.5,
    marker="x",
    markersize=2.5,
)
ax.tick_params(axis="x", rotation=90.0)
ax.set_xticks(range(0, len(flux_loops_names), 2))
ax.tick_params(axis="x", which="minor", pad=-20)
ax.grid(True, which="both", linewidth=0.3)
ax.set_xlim(0, len(flux_loops_names) - 1)
ax.legend()
ax.set_ylabel("Flux [Wb]")
# Out:
# Text(0, 0.5, 'Flux [Wb]')

# %%
# Compare bp_probes measured vs calculated value
bp_probes_names = bp_probes.keys()
bp_probes_measured = bp_probes.get_array2(["*", "b", "measured", "value"])[i_time, :]
bp_probes_calculated = bp_probes.get_array2(["*", "b", "calculated", "value"])[i_time, :]

fig, ax = plt.subplots(1, 1, figsize=(12, 4), dpi=110)
ax.plot(
    bp_probes_names,
    bp_probes_measured,
    label="Measured (FreeGSNKE)",
    color="blue",
    linewidth=0.5,
    marker="+",
    markersize=2.5,
)
ax.plot(
    bp_probes_names,
    bp_probes_calculated,
    label="Calculated (GSFit)",
    color="red",
    linestyle="dashed",
    linewidth=0.5,
    marker="x",
    markersize=2.5,
)
ax.tick_params(axis="x", rotation=90.0)
ax.set_xticks(range(0, len(bp_probes_names), 4))
ax.tick_params(axis="x", which="minor", pad=-20)
ax.grid(True, which="both", linewidth=0.3)
ax.set_xlim(0, len(bp_probes_names) - 1)
ax.legend()
ax.set_ylabel("Field [T]")
# Out:
# Text(0, 0.5, 'Field [T]')

# %%
# Check that the reconstructed plasma current is within 0.5 kA of the simulated plasma current
reconstructed_ip = gsfit_controller["GLOBAL"]["IP"][i_time]
print(f"Reconstructed Ip = {reconstructed_ip / 1e3:.2f} kA")
assert np.abs(reconstructed_ip - 600e3) < 0.5e3
# Out:
# Reconstructed Ip = 600.01 kA

# %%
def plot_pressure_along_midplane(freegsnke_eq, gsfit_controller):
    # Calculate the pressure on the mid-plane, for FreeGSNKE
    freegsnke_midplane_r = freegsnke_eq.R_1D
    freegsnke_midplane_z = 0.0 * freegsnke_midplane_r
    freegsnke_midplane_psi_n = freegsnke_eq.psiNRZ(freegsnke_midplane_r, freegsnke_midplane_z)
    freegsnke_midplane_pressure = freegsnke_eq.pressure(freegsnke_midplane_psi_n)

    # Calculate the pressure on the mid-plane, for GSFit
    plasma = gsfit_controller.plasma
    gsfit_p_midplane = plasma.get_array2(["profiles_1d", "r_midplane", "p"])
    gsfit_r_midplane = plasma.get_array1(["profiles_1d", "r_midplane", "r"])

    # Create figure
    plt.figure()

    # Plot the pressure on the mid-plane, for FreeGSNKE
    plt.plot(
        freegsnke_midplane_r,
        freegsnke_midplane_pressure,
        color="blue",
        label="FreeGSNKE",
        linewidth=0.5,
    )

    # Plot the pressure on the mid-plane, for GSFit
    plt.plot(
        gsfit_r_midplane,
        gsfit_p_midplane[0, :],
        label="GSFit",
        color="red",
        linestyle="dashed",
        linewidth=0.5,
    )
    plt.gca().set_xlabel("$R$ [m]")
    plt.gca().set_ylabel("$P$ [Pa]")

# %%
plot_pressure_along_midplane(freegsnke_eq, gsfit_controller)

# %% [markdown]
# ## 2.3 GSFit, magnetic + isoflux reconstruction
# We have already observed an excellent reconstruction of the last closed flux surface.
# However, the reconstruction of the pressure profile in the core, while close, is not exactly reconstructed.
# This is to be expected, as there were no internal measurements.
#
# We shall now try adding `isoflux` constraints.
# This requires us to specify two coordinates that have equal poloidal flux.
# To do this, we shall specify two HFS coordinates, interpolate the pressure, and find the corresponding LFS coordinate.

# %%
# Function to find the second location of the isoflux
def find_location_2_r(location_1_r, freegsnke_eq):
    # Note: This function assumes that we have kinetic measurements on the mid-plane.
    n_isoflux = len(location_1_r)

    # FreeGSNKE mid-plane pressure
    freegsnke_midplane_r = freegsnke_eq.R_1D
    freegsnke_midplane_z = 0.0 * freegsnke_midplane_r
    freegsnke_midplane_psi_n = freegsnke_eq.psiNRZ(freegsnke_midplane_r, freegsnke_midplane_z)
    freegsnke_midplane_pressure = freegsnke_eq.pressure(freegsnke_midplane_psi_n)

    # Find the pressure at (location_1_r, location_1_z); assuming location_1_z is 0.0
    location_2_r = np.full(n_isoflux, np.nan)
    isoflux_pressure = np.full(n_isoflux, np.nan)
    for i_isoflux in range(n_isoflux):
        pressure_line = shapely.geometry.LineString(np.column_stack((freegsnke_midplane_r, freegsnke_midplane_pressure)))
        line = shapely.geometry.LineString(np.column_stack(([location_1_r[i_isoflux], location_1_r[i_isoflux]], [0.0, 1e8])))
        isoflux_pressure_intersection = pressure_line.intersection(line)
        isoflux_pressure[i_isoflux] = isoflux_pressure_intersection.y

        isoflux_line = shapely.geometry.LineString(np.column_stack(([0.0, 10.0], [isoflux_pressure[i_isoflux], isoflux_pressure[i_isoflux]])))

        isoflux_intersections = isoflux_line.intersection(pressure_line)

        location_2_r[i_isoflux] = isoflux_intersections.geoms[1].x

    return location_2_r, isoflux_pressure


def plot_isoflux(freegsnke_eq, gsfit_controller, location_1_r, location_2_r, isoflux_pressure):
    # Plot the isoflux locations
    plot_pressure_along_midplane(freegsnke_eq, gsfit_controller)

    # Plot the isoflux locations
    n_isoflux = len(location_1_r)
    for i_isoflux in range(n_isoflux):
        plt.plot(
            [location_1_r[i_isoflux], location_2_r[i_isoflux]],
            [isoflux_pressure[i_isoflux], isoflux_pressure[i_isoflux]],
            color="black",
            linewidth=0.5,
            marker="o",
            markersize=5.0,
        )

# %%
# Calculate the pressure on the mid-plane, using FreeGSNKE
# We shall define two isoflux locations
location_1_r = np.array([0.6, 0.8])
location_1_z = np.array([0.0, 0.0])
location_2_z = np.array([0.0, 0.0])
location_2_r, isoflux_pressure = find_location_2_r(location_1_r, freegsnke_eq)
# Note: `isoflux_pressure` is only for plotting.

plot_isoflux(freegsnke_eq, gsfit_controller, location_1_r, location_2_r, isoflux_pressure)

# %%
isoflux = gsfit_rs.Isoflux()

times_to_reconstruct = gsfit_controller.results["TIME"]

n_time = 2
# Add an isoflux constraint to the GSFit controller
for i_isoflux in range(len(location_1_r)):
    isoflux.add_sensor(
        name=f"isoflux_constraint_{i_isoflux + 1}",
        fit_settings_comment="",
        fit_settings_include=True,
        fit_settings_weight=1.0,  # Large weight
        time=time,
        location_1_r=np.array([location_1_r[i_isoflux]] * n_time).astype(np.float64),
        location_1_z=np.array([0.0] * n_time).astype(np.float64),
        location_2_r=np.array([location_2_r[i_isoflux]] * n_time).astype(np.float64),
        location_2_z=np.array([0.0] * n_time).astype(np.float64),
        times_to_reconstruct=times_to_reconstruct,
    )

# Add the isoflux constraint to the GSFit controller
gsfit_controller.isoflux = isoflux

# We need to re-calculate the Greens tables
gsfit_controller.calculate_greens()

# Run the inverse solver
gsfit_controller.inverse_solver_rust()
# Out:
# 2026-07-18 21:37:57  |  GSFIT  |  gsfit.py:252                           |  INFO  |  Finished Greens with coils;  1,273.20ms
# 2026-07-18 21:37:57  |  GSFIT  |  gsfit.py:265                           |  INFO  |  Finished Greens with passives;  0.97ms
# 2026-07-18 21:37:59  |  GSFIT  |  gsfit.py:277                           |  INFO  |  Finished Greens with plasma;  1,523.54ms
# 2026-07-18 21:37:59  |  GSFIT  |  gsfit.py:198                           |  INFO  |  About to call: `gsfit_rs.solve_grad_shafranov`
# solve_grad_shafranov starting
# 2026-07-18 21:38:03  |  GSFIT  |  gsfit.py:222                           |  INFO  |  Finished: `gsfit_rs.solve_inverse_problem` time = 4,316.45ms
# time= 500.0ms;  solution_found=true;  gs_error=0.000000745169714813659;  n_iter=8
# equilibrium_post_processor: starting

# %%
# Plot how the results have changed with the isoflux constraint
plot_isoflux(freegsnke_eq, gsfit_controller, location_1_r, location_2_r, isoflux_pressure)
plot_2d_equilibrium(freegsnke_eq, gsfit_controller)

# %% [markdown]
# We observe that the 2D equilibrium is unchanged.
# The pressure profile now has the same shape as FreeGSNKE, but the magnitude is not correct.
# To further improve the equilibrium reconstruction, we will need to add in pressure constraints.

# %%
print(datetime.now())
# Out:
# 2026-07-18 21:38:19.096970
