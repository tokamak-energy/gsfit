# %% [markdown]
# In this example we create a FreeGS equilibrium **inspired** by experimental results.
#
# > **Note: this example will only run within Tokamak Energy's network**
#
# Then, we use the FreeGS magnetic sensors as measurements to run GSFit.
# This type of workflow is useful for sensitivity and "what if" modelling.
# For example:
# What are the optimal sensor weights and how sensitive is the result to the sensor weights?
# What if we add an extra PF coil?
# What if we add additional magnetic sensors?

# %%
import copy

import freegs
import matplotlib.pyplot as plt
import numpy as np
from freegs.machine import Machine
from freegs.machine import MultiCoil
from freegs.machine import Wall
from gsfit import Gsfit
from scipy import interpolate
from shapely.geometry import LineString
from shapely.geometry import Point
from st40_database import GetData

# Set the Matplotlib backend (inline=png; widget=interactive)
# %matplotlib inline
# %matplotlib widget

# Set the random seed for reproducibility
rng = np.random.default_rng(12345)

# %%
# Define what we want to reconstruct
pulseNo = 12050
times_to_reconstruct = 130.0e-3

# %%
# Set-up ST40 FreeGS PF coils
elmag_run_name = "RUN16"
elmag = GetData(11012050, f"ELMAG#{elmag_run_name}")

coils_r = elmag.get("COILS.R")
coils_z = elmag.get("COILS.Z")
coils_d_r = elmag.get("COILS.DR")
coils_d_z = elmag.get("COILS.DZ")
coil_names = elmag.get("COILS.COIL_NAMES")
fils2coils = elmag.get("COILS.FILS2COILS") == 1.0

psu2coil = GetData(12050, "PSU2COIL#RUN02")
time_experimental = psu2coil.get("TIME")

freegs_coils = []

for i_coil, coil_name in enumerate(coil_names):
    i_filaments = fils2coils[:, i_coil]
    coil_r = coils_r[i_filaments]
    coil_z = coils_z[i_filaments]
    coil_d_r = coils_d_r[i_filaments]
    coil_d_z = coils_d_z[i_filaments]
    n_turns = len(coil_r)
    # Skip the MCT, MCB, PSHT, and PSHB coils
    if coil_name == "MCT" or coil_name == "MCB" or coil_name == "PSHT" or coil_name == "PSHB":
        continue

    if coil_name == "SOL":
        current_experimental = psu2coil.get("PF.SOL.I")
        control = False
    elif coil_name == "DIVT" or coil_name == "DIVB":
        current_experimental = psu2coil.get("PF.DIV.I") * 1.00
        control = False
    elif coil_name == "BVUT":
        current_experimental = psu2coil.get("PF.BVUT.I") * 0.78
        control = True
    elif coil_name == "BVUB":
        current_experimental = psu2coil.get("PF.BVUT.I") * 0.78
        control = True
    elif coil_name == "BVL":
        current_experimental = psu2coil.get("PF.BVL.I") * 0.80  # Less BVL current to ensure the plasma is x-point diverted
        control = False
    else:
        current_experimental = psu2coil.get(f"PF.{coil_name[0:-1]}.I")
        control = False

    current = np.interp(times_to_reconstruct, time_experimental, current_experimental)
    coil = MultiCoil(coil_r, coil_z, current=current, control=control)
    freegs_coils.append((coil_name, coil))

# Set-up ST40 FreeGS magnetic sensors
# Initialize the sensors list
freegs_sensors = []

mag = GetData(pulseNo, "MAG#BEST")

# Add bp_probes
bp_names = mag.get("BPPROBE.ALL_000.NAMES")
for bp_name in bp_names:
    bp_name_short = bp_name.split("_")[1]
    angle = mag.get(f"BPPROBE.P{bp_name_short}.ANGLE")
    r = mag.get(f"BPPROBE.P{bp_name_short}.R")
    z = mag.get(f"BPPROBE.P{bp_name_short}.Z")

    # Add bp_sensors to the `tokamak` object
    freegs_sensor = freegs.machine.PoloidalFieldSensor(
        R=r,
        Z=z,
        theta=angle,
        name=f"P{bp_name_short}",
    )
    freegs_sensors.append(freegs_sensor)

# Add flux loop sensors
fl_names = mag.get("FLOOP.ALL.NAMES")
for fl_name in fl_names:
    fl_name_short = fl_name.split("_")[1]
    r = mag.get(f"FLOOP.L{fl_name_short}.R")
    z = mag.get(f"FLOOP.L{fl_name_short}.Z")

    # Add bp_sensors to the `tokamak` object
    freegs_sensor = freegs.machine.FluxLoopSensor(
        R=r,
        Z=z,
        name=f"L{fl_name_short}",
    )
    freegs_sensors.append(freegs_sensor)


# Plasma current
gsfit_database = GetData(12050, "GSFIT#TEST12")
time_gsfit_database = gsfit_database.get("TIME")
ip_experimental = gsfit_database.get("GLOBAL.IP")
ip = np.interp(times_to_reconstruct, time_gsfit_database, ip_experimental)
print(ip / 1e3, "kA")

# Set-up ST40 FreeGS Wall
r_limit_pts = elmag.get("LIMITER.LIMIT_PTS.R")
z_limit_pts = elmag.get("LIMITER.LIMIT_PTS.Z")
freegs_wall = Wall(r_limit_pts, z_limit_pts)

# Set-up ST40 FreeGS Machine
freegs_tokamak = Machine(
    coils=freegs_coils,
    wall=freegs_wall,
    sensors=freegs_sensors,
)

# Set-up ST40 FreeGS Equilibrium
freegs_eq = freegs.Equilibrium(
    tokamak=freegs_tokamak,
    Rmin=0.1,
    Rmax=1.0,
    Zmin=-1.0,
    Zmax=1.0,
    nx=129,
    ny=129,
    current=ip,
)

# Set-up ST40 FreeGS plasma profiles
profiles = freegs.jtor.ConstrainPaxisIp(
    eq=freegs_eq,
    paxis=40e3,  # Plasma pressure on axis [Pascals]
    Ip=ip,  # Plasma current [Amps]
    fvac=1.8 * 0.4,  # vacuum f = R*Bt
    alpha_m=1.0,
    alpha_n=1.0,
)

# To avoid the VDE, we need to add constraints
xpoints = [
    (0.328, -0.532),  # (R,Z) locations of X-points
    (0.328, 0.535),  # (R,Z) locations of X-points
]
constrain = freegs.control.constrain(xpoints)

# Solve the Grad-Shafranov equation
freegs.solve(
    freegs_eq,  # The equilibrium object
    profiles,
    constrain=constrain,  # Forward solver, no constraints
    show=False,  # Don't plot results while solving
)

# Take measurements
freegs_eq.tokamak.takeMeasurements(eq=freegs_eq)

# Plot the equilibrium solution
freegs_eq.plot()
# Out:
# Warning: No O points found

# %%
gsfit_controller = Gsfit(
    pulseNo=None,
    run_name="test_01",
    run_description="using FreeGS to generate measurements",
    settings_path="st40_all_magnetic_sensors_working",
    write_to_mds=False,
)
gsfit_controller.settings["GSFIT_code_settings.json"]["database_reader"]["method"] = "freegs"
gsfit_controller.settings["GSFIT_code_settings.json"]["timeslices"]["method"] = "user_defined"
gsfit_controller.settings["GSFIT_code_settings.json"]["timeslices"]["user_defined"] = [0.5]

gsfit_controller.run(time=np.array([0.0, 1.0]), freegs_eqs=[freegs_eq, freegs_eq])
# Out:
# 2026-04-08 09:32:33  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "GSFIT_code_settings.json"
# 2026-04-08 09:32:33  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "passive_dof_regularisation.json"
# 2026-04-08 09:32:33  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "sensor_weights_bp_probe.json"
# 2026-04-08 09:32:33  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "sensor_weights_dialoop.json"
# 2026-04-08 09:32:33  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "sensor_weights_flux_loops.json"
# 2026-04-08 09:32:33  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "sensor_weights_isoflux.json"
# 2026-04-08 09:32:33  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "sensor_weights_pressure.json"
# 2026-04-08 09:32:33  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "sensor_weights_rogowski_coils.json"
# 2026-04-08 09:32:33  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "source_function_ff_prime.json"
# 2026-04-08 09:32:33  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "source_function_p_prime.json"
# 2026-04-08 09:32:33  |  GSFIT  |  gsfit.py:92                            |  INFO  |  Running Gsfit, for pulseNo=None
# 2026-04-08 09:32:33  |  GSFIT  |  gsfit.py:290                           |  INFO  |  `coils`  initialised;  0.29ms
# 2026-04-08 09:32:33  |  GSFIT  |  gsfit.py:295                           |  INFO  |  `bp_probes` initialised;  0.40ms
# 2026-04-08 09:32:33  |  GSFIT  |  gsfit.py:300                           |  INFO  |  `flux_loops` initialised;  0.50ms
# 2026-04-08 09:32:33  |  GSFIT  |  gsfit.py:305                           |  INFO  |  `rogowski_coils` initialised;  0.05ms
# 2026-04-08 09:32:33  |  GSFIT  |  gsfit.py:310                           |  INFO  |  `passives` initialised;  0.01ms
# 2026-04-08 09:32:34  |  GSFIT  |  gsfit.py:315                           |  INFO  |  `plasma` initialised;  621.67ms
# 2026-04-08 09:32:34  |  GSFIT  |  gsfit.py:321                           |  INFO  |  `isoflux` initialised;  0.02ms
# 2026-04-08 09:32:34  |  GSFIT  |  gsfit.py:326                           |  INFO  |  `isoflux_boundary` initialised;  0.01ms
# 2026-04-08 09:32:34  |  GSFIT  |  gsfit.py:331                           |  INFO  |  `pressure_sensors` initialised;  0.01ms
# 2026-04-08 09:32:34  |  GSFIT  |  gsfit.py:341                           |  INFO  |  `stationary_point` initialised;  0.01ms
# 2026-04-08 09:32:37  |  GSFIT  |  gsfit.py:243                           |  INFO  |  Finished Greens with coils;  3,017.19ms
# 2026-04-08 09:32:37  |  GSFIT  |  gsfit.py:256                           |  INFO  |  Finished Greens with passives;  0.32ms
# 2026-04-08 09:32:37  |  GSFIT  |  gsfit.py:268                           |  INFO  |  Finished Greens with plasma;  296.08ms
# 2026-04-08 09:32:37  |  GSFIT  |  gsfit.py:190                           |  INFO  |  About to call: `gsfit_rs.solve_grad_shafranov`
# solve_grad_shafranov starting
# 2026-04-08 09:32:58  |  GSFIT  |  gsfit.py:213                           |  INFO  |  Finished: `gsfit_rs.solve_inverse_problem` time = 20,622.12ms
# time= 500.0ms;  solution_found=true;  gs_error=0.0000040205726592078095;  n_iter=12
# equilibrium_post_processor: starting
# 2026-04-08 09:32:58  |  GSFIT  |  gsfit.py:130                           |  INFO  |  pulseNo = None pulseNo_write = None run_name = TEST_01

# %%
# Compare the FreeGS equilibrium to the GSFit equilibrium
freegs_r = freegs_eq.R
freegs_z = freegs_eq.Z
freegs_r_1d = freegs_eq.R_1D
freegs_z_1d = freegs_eq.Z_1D
freegs_psi = freegs_eq.psiRZ(freegs_r, freegs_z).T * (2.0 * np.pi)  # Convert from Wb/(2*pi) to Wb
freegs_psi_b = freegs_eq.psi_bndry * (2.0 * np.pi)

# Note: we will plot with the same `psi_range` for FreeGS and GSFit
psi_range = np.linspace(np.min(freegs_psi), np.max(freegs_psi), 30)

i_time = 0  # only one time-slice
gsfit_psi = gsfit_controller["TWO_D"]["PSI"][i_time, :, :]
gsfir_r = gsfit_controller.plasma.get_array1(["grid", "r"])
gsfit_z = gsfit_controller.plasma.get_array1(["grid", "z"])
gsfit_no_noise_rbnd = gsfit_controller.plasma.get_array2(["p_boundary", "rbnd"])[i_time, :]
gsfit_no_noise_zbnd = gsfit_controller.plasma.get_array2(["p_boundary", "zbnd"])[i_time, :]
bounding_r = gsfit_controller.plasma.get_array1(["p_boundary", "bounding_r"])
bounding_z = gsfit_controller.plasma.get_array1(["p_boundary", "bounding_z"])

plt.figure()
plt.gca().set_aspect("equal")
plt.plot(r_limit_pts, z_limit_pts, color="black", linewidth=0.5)

plt.contour(freegs_r_1d, freegs_z_1d, freegs_psi, levels=psi_range, colors="blue", linewidths=0.25, linestyles="solid")
plt.contour(freegs_r_1d, freegs_z_1d, freegs_psi, [freegs_psi_b], colors="blue", linewidths=0.75, linestyles="solid")  # , label="FreeGS"

plt.contour(gsfir_r, gsfit_z, gsfit_psi, levels=psi_range, colors="red", linewidths=0.25, linestyles="dashed")
plt.plot(gsfit_no_noise_rbnd, gsfit_no_noise_zbnd, color="red", linewidth=0.75, linestyle="dashed", label="GSFit")
plt.plot(bounding_r[i_time], bounding_z[i_time], marker="s", color="red")

# %%
freegs_d_psi_d_z, freegs_d_psi_d_r = np.gradient(freegs_psi, freegs_z_1d, freegs_r_1d)
freegs_br = -(1.0 / (2.0 * np.pi * freegs_r_1d)) * freegs_d_psi_d_z
freegs_bz = (1.0 / (2.0 * np.pi * freegs_r_1d)) * freegs_d_psi_d_r

f_br = interpolate.RectBivariateSpline(freegs_z_1d, freegs_r_1d, freegs_br)
f_bz = interpolate.RectBivariateSpline(freegs_z_1d, freegs_r_1d, freegs_bz)

b_check = []
for sensor_name in gsfit_controller.bp_probes.keys():
    r = gsfit_controller.bp_probes.get_f64([sensor_name, "geometry", "r"])
    z = gsfit_controller.bp_probes.get_f64([sensor_name, "geometry", "z"])
    angle_pol = gsfit_controller.bp_probes.get_f64([sensor_name, "geometry", "angle_pol"])
    value = f_br(z, r)[0, 0] * np.cos(angle_pol) + f_bz(z, r)[0, 0] * np.sin(angle_pol)
    b_check.append(value)


def plot_magnetic_probes(gsfit_controller: Gsfit):
    _fig, ax = plt.subplots(1, 2, figsize=(12, 4), dpi=110)

    time = gsfit_controller.plasma.get_array1(["time"])
    n_time = len(time)

    # Bp probes
    bp_probes = gsfit_controller.bp_probes
    measured = bp_probes.get_array2(["*", "b", "measured", "value"])
    bp_probe_names = bp_probes.keys()
    for i_time in range(0, n_time):
        ax[0].plot(bp_probe_names, measured[i_time, :], linewidth=0.25)
    ax[0].tick_params(axis="x", rotation=90.0)
    ax[0].set_xticks(range(0, len(bp_probe_names), 2))
    ax[0].set_ylabel("B [T]")

    # Flux loops
    flux_loops = gsfit_controller.flux_loops
    measured = flux_loops.get_array2(["*", "psi", "measured", "value"])
    flux_loops_names = flux_loops.keys()
    for i_time in range(0, n_time):
        ax[1].plot(flux_loops_names, measured[i_time, :], linewidth=0.25)
    ax[1].tick_params(axis="x", rotation=90.0)
    ax[1].set_xticks(range(0, len(flux_loops_names), 2))
    ax[1].set_ylabel("Flux [Wb]")


plot_magnetic_probes(gsfit_controller)

# %%
psi_n = gsfit_controller.plasma.get_array1(["profiles", "psi_n"])
p_prime = gsfit_controller.plasma.get_array2(["profiles", "p_prime"])[0, :]
ff_prime = gsfit_controller.plasma.get_array2(["profiles", "ff_prime"])[0, :]

freegs_p_prime = freegs_eq.pprime(psi_n)
freegs_ff_prime = freegs_eq.ffprime(psi_n)

plt.figure()
plt.plot(psi_n, freegs_p_prime / (2.0 * np.pi), label="FreeGS p'")
plt.plot(psi_n, p_prime, label="GSFit p'")

plt.figure()
plt.plot(psi_n, freegs_ff_prime / (2.0 * np.pi), label="FreeGS ff'")
plt.plot(psi_n, ff_prime, label="GSFit ff'")

# %% [markdown]
# Instead of adding random noise to the measurement.
# I should add the random error to the probe positions.

# %%
# Add random noise to the measurements
n_random_scans = 350  # more than 350 becomes quite slow

# Add random noise to the positions of the magnetic sensors
freegs_eqs_with_random_noise = []
freegs_eqs_with_random_noise.append(freegs_eq)  # The original equilibrium comes first
for i_random_scan in range(1, n_random_scans):
    freegs_eq_with_random_noise = copy.deepcopy(freegs_eq)
    # Use the rng Generator for deterministic random noise
    for i_sensor, sensor in enumerate(freegs_eq.tokamak.sensors):
        # measurement = sensor.measurement
        r_sensor = sensor.R
        z_sensor = sensor.Z

        # Add random normal noise to the sensor positions
        freegs_eq_with_random_noise.tokamak.sensors[i_sensor].R = rng.normal(r_sensor, 2e-3)
        freegs_eq_with_random_noise.tokamak.sensors[i_sensor].Z = rng.normal(z_sensor, 2e-3)

        try:
            angle_no_noise = sensor.theta
            freegs_eq_with_random_noise.tokamak.sensors[i_sensor].theta = rng.normal(angle_no_noise, np.deg2rad(2.5))
        except:
            pass

    # Take measurements
    freegs_eq_with_random_noise.tokamak.takeMeasurements(eq=freegs_eq_with_random_noise)

    # Append the modified equilibrium to the list to be reconstructed
    freegs_eqs_with_random_noise.append(freegs_eq_with_random_noise)

# %%
# GSFit reconstruction with random noise
time = np.linspace(0.0, 1.0, n_random_scans)
gsfit_controller.settings["GSFIT_code_settings.json"]["timeslices"]["method"] = "user_defined"
gsfit_controller.settings["GSFIT_code_settings.json"]["timeslices"]["user_defined"] = time.tolist()

# Solve with random noise
gsfit_controller.run(time=time, freegs_eqs=freegs_eqs_with_random_noise)
# Out:
# 2026-04-08 09:41:57  |  GSFIT  |  gsfit.py:92                            |  INFO  |  Running Gsfit, for pulseNo=None
# 2026-04-08 09:41:57  |  GSFIT  |  gsfit.py:290                           |  INFO  |  `coils`  initialised;  0.43ms
# 2026-04-08 09:41:57  |  GSFIT  |  gsfit.py:295                           |  INFO  |  `bp_probes` initialised;  7.47ms
# 2026-04-08 09:41:57  |  GSFIT  |  gsfit.py:300                           |  INFO  |  `flux_loops` initialised;  7.74ms
# 2026-04-08 09:41:57  |  GSFIT  |  gsfit.py:305                           |  INFO  |  `rogowski_coils` initialised;  0.34ms
# 2026-04-08 09:41:57  |  GSFIT  |  gsfit.py:310                           |  INFO  |  `passives` initialised;  0.01ms
# 2026-04-08 09:41:58  |  GSFIT  |  gsfit.py:315                           |  INFO  |  `plasma` initialised;  638.97ms
# 2026-04-08 09:41:58  |  GSFIT  |  gsfit.py:321                           |  INFO  |  `isoflux` initialised;  0.03ms
# 2026-04-08 09:41:58  |  GSFIT  |  gsfit.py:326                           |  INFO  |  `isoflux_boundary` initialised;  0.01ms
# 2026-04-08 09:41:58  |  GSFIT  |  gsfit.py:331                           |  INFO  |  `pressure_sensors` initialised;  0.01ms
# 2026-04-08 09:41:58  |  GSFIT  |  gsfit.py:341                           |  INFO  |  `stationary_point` initialised;  0.01ms
# 2026-04-08 09:42:01  |  GSFIT  |  gsfit.py:243                           |  INFO  |  Finished Greens with coils;  3,002.25ms
# 2026-04-08 09:42:01  |  GSFIT  |  gsfit.py:256                           |  INFO  |  Finished Greens with passives;  0.32ms
# 2026-04-08 09:42:01  |  GSFIT  |  gsfit.py:268                           |  INFO  |  Finished Greens with plasma;  318.61ms
# 2026-04-08 09:42:01  |  GSFIT  |  gsfit.py:190                           |  INFO  |  About to call: `gsfit_rs.solve_grad_shafranov`
# solve_grad_shafranov starting
# 2026-04-08 09:47:46  |  GSFIT  |  gsfit.py:213                           |  INFO  |  Finished: `gsfit_rs.solve_inverse_problem` time = 345,249.73ms
# time= 544.4ms;  solution_found=true;  gs_error=0.00000037021229327071997;  n_iter=9
# time= 375.4ms;  solution_found=true;  gs_error=0.000003792823865851747;  n_iter=12
# time= 750.7ms;  solution_found=true;  gs_error=0.000004179835703876199;  n_iter=12
# time=   0.0ms;  solution_found=true;  gs_error=0.0000040205726592078095;  n_iter=12
# time= 232.1ms;  solution_found=true;  gs_error=0.0000039837418403309585;  n_iter=12
# time=  43.0ms;  solution_found=true;  gs_error=0.000004451741661972095;  n_iter=12
# time=   2.9ms;  solution_found=true;  gs_error=0.000003989567621138059;  n_iter=12
# time=   8.6ms;  solution_found=true;  gs_error=0.0000037967800397288625;  n_iter=12
# time= 186.2ms;  solution_found=true;  gs_error=0.000003969627937672259;  n_iter=12
# time= 249.3ms;  solution_found=true;  gs_error=0.000003782194452123253;  n_iter=12
# time= 123.2ms;  solution_found=true;  gs_error=0.000004008446528197858;  n_iter=12
# time=  40.1ms;  solution_found=true;  gs_error=0.0000041492030787096895;  n_iter=12
# time= 154.7ms;  solution_found=true;  gs_error=0.0000036307167812141037;  n_iter=12
# time=  37.2ms;  solution_found=true;  gs_error=0.000004203905343099829;  n_iter=12
# time=  14.3ms;  solution_found=true;  gs_error=0.000004133798243169612;  n_iter=12
# time= 530.1ms;  solution_found=true;  gs_error=0.000003990811899658944;  n_iter=12
# time= 137.5ms;  solution_found=true;  gs_error=0.000003969723855056946;  n_iter=12
# time= 561.6ms;  solution_found=true;  gs_error=0.000004237327559406283;  n_iter=12
# time=   5.7ms;  solution_found=true;  gs_error=0.00000394745523507561;  n_iter=12
# time=  34.4ms;  solution_found=true;  gs_error=0.000004043898411828017;  n_iter=12
# time= 656.2ms;  solution_found=true;  gs_error=0.0000037041924871476057;  n_iter=12
# time= 575.9ms;  solution_found=true;  gs_error=0.0000038363412899669594;  n_iter=12
# time= 501.4ms;  solution_found=true;  gs_error=0.000004114534217778036;  n_iter=12
# time= 593.1ms;  solution_found=true;  gs_error=0.000003877881450865832;  n_iter=12
# time= 687.7ms;  solution_found=true;  gs_error=0.000003821705750851799;  n_iter=12
# time= 128.9ms;  solution_found=true;  gs_error=0.000003911363559324718;  n_iter=12
# time= 217.8ms;  solution_found=true;  gs_error=0.000003990498950199767;  n_iter=12
# time= 624.6ms;  solution_found=true;  gs_error=0.000003955579917932217;  n_iter=12
# time=  60.2ms;  solution_found=true;  gs_error=0.0000036535185501024135;  n_iter=12
# time=  28.7ms;  solution_found=true;  gs_error=0.0000036870650568339214;  n_iter=12
# time= 719.2ms;  solution_found=true;  gs_error=0.000003781695103375102;  n_iter=12
# time= 312.3ms;  solution_found=true;  gs_error=0.000004283568372623284;  n_iter=12
# time= 547.3ms;  solution_found=true;  gs_error=0.0000037999336461551727;  n_iter=12
# time= 126.1ms;  solution_found=true;  gs_error=0.000001157275288164455;  n_iter=9
# time= 627.5ms;  solution_found=true;  gs_error=0.000004314053568817378;  n_iter=9
# time= 140.4ms;  solution_found=true;  gs_error=0.000004724244730190158;  n_iter=9
# time=  63.0ms;  solution_found=true;  gs_error=0.0000033143660532182194;  n_iter=9
# time= 596.0ms;  solution_found=true;  gs_error=0.000003323108866915149;  n_iter=10
# time= 378.2ms;  solution_found=true;  gs_error=0.0000044592903683193005;  n_iter=12
# time= 753.6ms;  solution_found=true;  gs_error=0.0000036864454458069386;  n_iter=12
# time=  45.8ms;  solution_found=true;  gs_error=0.000004226251827317238;  n_iter=12
# time=  20.1ms;  solution_found=true;  gs_error=0.000003914899732063477;  n_iter=12
# time= 235.0ms;  solution_found=true;  gs_error=0.000004158637443593424;  n_iter=12
# time=  51.6ms;  solution_found=true;  gs_error=0.000004003511173268701;  n_iter=12
# time= 252.1ms;  solution_found=true;  gs_error=0.00000386485238694905;  n_iter=12
# time=  11.5ms;  solution_found=true;  gs_error=0.0000037598204574746264;  n_iter=12
# time= 189.1ms;  solution_found=true;  gs_error=0.000003897242869502263;  n_iter=12
# time= 157.6ms;  solution_found=true;  gs_error=0.0000041449185398887785;  n_iter=12
# time= 169.1ms;  solution_found=true;  gs_error=0.00000409420540465663;  n_iter=12
# time= 702.0ms;  solution_found=true;  gs_error=0.0000042394488338572965;  n_iter=12
# time= 315.2ms;  solution_found=true;  gs_error=0.000004449689213866236;  n_iter=12
# time= 670.5ms;  solution_found=true;  gs_error=0.000004176147529565001;  n_iter=12
# time= 690.5ms;  solution_found=true;  gs_error=0.000004343681302447017;  n_iter=12
# time= 131.8ms;  solution_found=true;  gs_error=0.000004229730476571075;  n_iter=12
# time= 578.8ms;  solution_found=true;  gs_error=0.000003714090062393372;  n_iter=12
# time= 659.0ms;  solution_found=true;  gs_error=0.000003941147729024829;  n_iter=12
# time= 220.6ms;  solution_found=true;  gs_error=0.000004329477358439067;  n_iter=12
# time=  31.5ms;  solution_found=true;  gs_error=0.000004098667249540027;  n_iter=12
# time= 160.5ms;  solution_found=true;  gs_error=0.000003913663537409482;  n_iter=12
# time= 564.5ms;  solution_found=true;  gs_error=0.000003944886860488855;  n_iter=12
# time=  17.2ms;  solution_found=true;  gs_error=0.000003945456223182426;  n_iter=12
# time= 533.0ms;  solution_found=true;  gs_error=0.0000037517914382297017;  n_iter=12
# time= 504.3ms;  solution_found=true;  gs_error=0.00000384671426699784;  n_iter=12
# time= 722.1ms;  solution_found=true;  gs_error=0.0000037690406333771572;  n_iter=12
# time=  65.9ms;  solution_found=true;  gs_error=0.000003808726798527455;  n_iter=9
# time= 550.1ms;  solution_found=true;  gs_error=0.000004049292194509557;  n_iter=12
# time= 630.4ms;  solution_found=true;  gs_error=0.000003734309110497407;  n_iter=12
# time= 280.8ms;  solution_found=true;  gs_error=0.0000024137118107118576;  n_iter=9
# time= 143.3ms;  solution_found=true;  gs_error=0.000004023770168813547;  n_iter=12
# time= 756.4ms;  solution_found=true;  gs_error=0.000004059458051264497;  n_iter=12
# time= 381.1ms;  solution_found=true;  gs_error=0.000003913788997235674;  n_iter=12
# time= 598.9ms;  solution_found=true;  gs_error=0.0000039837978321580644;  n_iter=12
# time=  48.7ms;  solution_found=true;  gs_error=0.000003549515086379334;  n_iter=12
# time= 134.7ms;  solution_found=true;  gs_error=0.000004056534668606584;  n_iter=12
# time= 710.6ms;  solution_found=true;  gs_error=0.000004091862142189347;  n_iter=12
# time=  22.9ms;  solution_found=true;  gs_error=0.000003759927167881695;  n_iter=12
# time= 192.0ms;  solution_found=true;  gs_error=0.000004251979035312451;  n_iter=12
# time=  54.4ms;  solution_found=true;  gs_error=0.000004209167597279851;  n_iter=12
# time= 255.0ms;  solution_found=true;  gs_error=0.000004255442285063411;  n_iter=12
# time= 318.1ms;  solution_found=true;  gs_error=0.0000041167080569280325;  n_iter=12
# time= 237.8ms;  solution_found=true;  gs_error=0.000004016290056190537;  n_iter=12
# time= 171.9ms;  solution_found=true;  gs_error=0.0000039012736471297375;  n_iter=12
# time= 661.9ms;  solution_found=true;  gs_error=0.000003837400068752329;  n_iter=12
# time= 673.4ms;  solution_found=true;  gs_error=0.000003831626983074251;  n_iter=12
# time= 693.4ms;  solution_found=true;  gs_error=0.0000041343280079361705;  n_iter=12
# time= 581.7ms;  solution_found=true;  gs_error=0.000004438608386606976;  n_iter=12
# time= 704.9ms;  solution_found=true;  gs_error=0.000003855237924411411;  n_iter=12
# time= 679.1ms;  solution_found=true;  gs_error=0.0000036273908158954947;  n_iter=12
# time= 163.3ms;  solution_found=true;  gs_error=0.000004026029541599504;  n_iter=12
# time= 223.5ms;  solution_found=true;  gs_error=0.000003867790719042902;  n_iter=12
# time= 567.3ms;  solution_found=true;  gs_error=0.000004274112072619066;  n_iter=12
# time= 240.7ms;  solution_found=true;  gs_error=0.000004192758913621325;  n_iter=12
# time= 535.8ms;  solution_found=true;  gs_error=0.000003830364461127382;  n_iter=12
# time= 515.8ms;  solution_found=true;  gs_error=0.000004098980334317559;  n_iter=12
# time= 724.9ms;  solution_found=true;  gs_error=0.00000407712589806045;  n_iter=12
# time= 507.2ms;  solution_found=true;  gs_error=0.0000038100903133873355;  n_iter=12
# time=  68.8ms;  solution_found=true;  gs_error=0.000004235899457721624;  n_iter=12
# time= 553.0ms;  solution_found=true;  gs_error=0.000003951179456279516;  n_iter=12
# time= 326.6ms;  solution_found=true;  gs_error=0.000003897195302977476;  n_iter=9
# time= 174.8ms;  solution_found=true;  gs_error=0.000004990336147506302;  n_iter=9
# time= 633.2ms;  solution_found=true;  gs_error=0.000004015108803504762;  n_iter=12
# time= 146.1ms;  solution_found=true;  gs_error=0.0000039129625060962905;  n_iter=12
# time= 384.0ms;  solution_found=true;  gs_error=0.0000037774020185613753;  n_iter=12
# time= 283.7ms;  solution_found=true;  gs_error=0.000004367873761061256;  n_iter=12
# time= 759.3ms;  solution_found=true;  gs_error=0.0000037525842989702698;  n_iter=12
# time=  25.8ms;  solution_found=true;  gs_error=0.00000413263232277757;  n_iter=12
# time= 713.5ms;  solution_found=true;  gs_error=0.000004230763040220954;  n_iter=12
# time= 194.8ms;  solution_found=true;  gs_error=0.000004037972216180648;  n_iter=12
# time= 320.9ms;  solution_found=true;  gs_error=0.0000037377702086606323;  n_iter=12
# time=  57.3ms;  solution_found=true;  gs_error=0.000004291818643654045;  n_iter=12
# time= 601.7ms;  solution_found=true;  gs_error=0.000003885395531377685;  n_iter=12
# time= 343.8ms;  solution_found=true;  gs_error=0.0000040502650527002776;  n_iter=12
# time= 257.9ms;  solution_found=true;  gs_error=0.000004173597049459497;  n_iter=12
# time= 707.7ms;  solution_found=true;  gs_error=0.000004002064352682302;  n_iter=12
# time= 510.0ms;  solution_found=true;  gs_error=0.000004106075801785519;  n_iter=12
# time= 664.8ms;  solution_found=true;  gs_error=0.000004320017922282277;  n_iter=12
# time= 696.3ms;  solution_found=true;  gs_error=0.000003888148079598718;  n_iter=12
# time= 681.9ms;  solution_found=true;  gs_error=0.000003961957058071951;  n_iter=12
# time= 676.2ms;  solution_found=true;  gs_error=0.000003940578534233166;  n_iter=12
# time= 584.5ms;  solution_found=true;  gs_error=0.000003841372529137925;  n_iter=12
# time= 226.4ms;  solution_found=true;  gs_error=0.000003963776670052468;  n_iter=12
# time= 727.8ms;  solution_found=true;  gs_error=0.000004159311541596828;  n_iter=12
# time= 243.6ms;  solution_found=true;  gs_error=0.000003824831815553833;  n_iter=12
# time= 570.2ms;  solution_found=true;  gs_error=0.0000037508992218454553;  n_iter=12
# time= 166.2ms;  solution_found=true;  gs_error=0.000003822677726107643;  n_iter=12
# time= 607.4ms;  solution_found=true;  gs_error=0.000004116208841032535;  n_iter=12
# time= 538.7ms;  solution_found=true;  gs_error=0.000003979919164604414;  n_iter=12
# time= 518.6ms;  solution_found=true;  gs_error=0.000004111338568352398;  n_iter=12
# time= 286.5ms;  solution_found=true;  gs_error=0.0000015116022456989748;  n_iter=9
# time= 733.5ms;  solution_found=true;  gs_error=0.0000006114339327153296;  n_iter=8
# time=  71.6ms;  solution_found=true;  gs_error=0.000004156533177513829;  n_iter=12
# time= 716.3ms;  solution_found=true;  gs_error=0.000002352901073718522;  n_iter=9
# time= 555.9ms;  solution_found=true;  gs_error=0.000004028674844550333;  n_iter=12
# time= 346.7ms;  solution_found=true;  gs_error=0.000003715195228748537;  n_iter=9
# time= 876.8ms;  solution_found=true;  gs_error=0.000004815955715287119;  n_iter=8
# time= 329.5ms;  solution_found=true;  gs_error=0.000004196597709840204;  n_iter=12
# time= 177.7ms;  solution_found=true;  gs_error=0.000003878653639465877;  n_iter=12
# time= 149.0ms;  solution_found=true;  gs_error=0.000003851290412430232;  n_iter=12
# time= 386.8ms;  solution_found=true;  gs_error=0.000004146853186480987;  n_iter=12
# time= 762.2ms;  solution_found=true;  gs_error=0.000003893501104832565;  n_iter=12
# time= 197.7ms;  solution_found=true;  gs_error=0.0000039143175845314905;  n_iter=12
# time= 636.1ms;  solution_found=true;  gs_error=0.000004192447445367392;  n_iter=12
# time= 323.8ms;  solution_found=true;  gs_error=0.000003528045604621746;  n_iter=12
# time= 200.6ms;  solution_found=true;  gs_error=0.00000022314156475590793;  n_iter=9
# time= 639.0ms;  solution_found=true;  gs_error=0.000004421731364951974;  n_iter=12
# time= 263.6ms;  solution_found=true;  gs_error=0.00000404606061794931;  n_iter=12
# time= 260.7ms;  solution_found=true;  gs_error=0.000004057888844139788;  n_iter=12
# time= 667.6ms;  solution_found=true;  gs_error=0.000003884185803876346;  n_iter=12
# time= 604.6ms;  solution_found=true;  gs_error=0.000003995026841559048;  n_iter=12
# time= 512.9ms;  solution_found=true;  gs_error=0.000003971127228139244;  n_iter=12
# time= 229.2ms;  solution_found=true;  gs_error=0.000004174230602023728;  n_iter=12
# time= 684.8ms;  solution_found=true;  gs_error=0.000004095001917206122;  n_iter=12
# time= 730.7ms;  solution_found=true;  gs_error=0.0000042849259179843846;  n_iter=12
# time= 587.4ms;  solution_found=true;  gs_error=0.000004089375310079105;  n_iter=12
# time= 699.1ms;  solution_found=true;  gs_error=0.0000039201614188381355;  n_iter=12
# time= 573.1ms;  solution_found=true;  gs_error=0.000003977258628395028;  n_iter=12
# time= 541.5ms;  solution_found=true;  gs_error=0.000004109232741948077;  n_iter=12
# time= 246.4ms;  solution_found=true;  gs_error=0.000004039482577613016;  n_iter=12
# time= 521.5ms;  solution_found=true;  gs_error=0.000004027208048196093;  n_iter=12
# time= 610.3ms;  solution_found=true;  gs_error=0.000003858519857081407;  n_iter=12
# time= 289.4ms;  solution_found=true;  gs_error=0.0000031040680321979937;  n_iter=9
# time= 879.7ms;  solution_found=true;  gs_error=0.0000008671627935829123;  n_iter=9
# time= 736.4ms;  solution_found=true;  gs_error=0.0000037061753277711703;  n_iter=12
# time=  74.5ms;  solution_found=true;  gs_error=0.000004067551632960926;  n_iter=12
# time= 813.8ms;  solution_found=true;  gs_error=0.000003983957438234854;  n_iter=12
# time= 558.7ms;  solution_found=true;  gs_error=0.000003921142918531181;  n_iter=12
# time= 180.5ms;  solution_found=true;  gs_error=0.000004084444214746261;  n_iter=12
# time= 349.6ms;  solution_found=true;  gs_error=0.000004094699927124937;  n_iter=12
# time= 332.4ms;  solution_found=true;  gs_error=0.000004373498398363368;  n_iter=12
# time= 151.9ms;  solution_found=true;  gs_error=0.0000036900439855036352;  n_iter=12
# time= 765.0ms;  solution_found=true;  gs_error=0.00000379850325021122;  n_iter=12
# time= 389.7ms;  solution_found=true;  gs_error=0.000003970743191340386;  n_iter=12
# time= 295.1ms;  solution_found=true;  gs_error=0.00000013156251732215762;  n_iter=9
# time= 358.2ms;  solution_found=true;  gs_error=0.000004241453644702829;  n_iter=12
# time= 641.8ms;  solution_found=true;  gs_error=0.000004385514635374697;  n_iter=12
# time= 203.4ms;  solution_found=true;  gs_error=0.00000403609160069527;  n_iter=12
# time= 335.2ms;  solution_found=true;  gs_error=0.000004039046307154144;  n_iter=12
# time= 782.2ms;  solution_found=true;  gs_error=0.000004268951874066347;  n_iter=12
# time= 524.4ms;  solution_found=true;  gs_error=0.0000037593874548543013;  n_iter=12
# time= 266.5ms;  solution_found=true;  gs_error=0.0000034671333537807416;  n_iter=12
# time= 742.1ms;  solution_found=true;  gs_error=0.000004011821462069106;  n_iter=12
# time= 183.4ms;  solution_found=true;  gs_error=0.0000037473332235413007;  n_iter=12
# time= 739.3ms;  solution_found=true;  gs_error=0.0000038049575298502512;  n_iter=12
# time= 292.3ms;  solution_found=true;  gs_error=0.0000040484277058770316;  n_iter=12
# time= 209.2ms;  solution_found=true;  gs_error=0.000004180643492608123;  n_iter=12
# time= 590.3ms;  solution_found=true;  gs_error=0.000004085978537032078;  n_iter=12
# time= 845.3ms;  solution_found=true;  gs_error=0.000003868443813608306;  n_iter=12
# time= 859.6ms;  solution_found=true;  gs_error=0.000004012248592413752;  n_iter=12
# time= 338.1ms;  solution_found=true;  gs_error=0.000004245035113522435;  n_iter=12
# time= 851.0ms;  solution_found=true;  gs_error=0.0000035083554782769004;  n_iter=12
# time= 773.6ms;  solution_found=true;  gs_error=0.00000415192268788789;  n_iter=12
# time= 613.2ms;  solution_found=true;  gs_error=0.000004384930858717718;  n_iter=12
# time= 647.6ms;  solution_found=true;  gs_error=0.000004245918834241669;  n_iter=12
# time= 882.5ms;  solution_found=true;  gs_error=0.000003944834956727105;  n_iter=12
# time= 361.0ms;  solution_found=true;  gs_error=0.000002599252782817377;  n_iter=9
# time= 848.1ms;  solution_found=true;  gs_error=0.0000038084287457314737;  n_iter=12
# time=  77.4ms;  solution_found=true;  gs_error=0.00000390115380212125;  n_iter=12
# time= 816.6ms;  solution_found=true;  gs_error=0.0000037463820217496285;  n_iter=12
# time= 272.2ms;  solution_found=true;  gs_error=0.000003973174456678507;  n_iter=12
# time= 352.4ms;  solution_found=true;  gs_error=0.000003960716700534031;  n_iter=12
# time= 767.9ms;  solution_found=true;  gs_error=0.00000394753153125339;  n_iter=12
# time= 206.3ms;  solution_found=true;  gs_error=0.000004490390022541031;  n_iter=12
# time= 644.7ms;  solution_found=true;  gs_error=0.000003842192954949341;  n_iter=12
# time= 438.4ms;  solution_found=true;  gs_error=0.000004161451381456908;  n_iter=12
# time= 298.0ms;  solution_found=true;  gs_error=0.000004054735969038825;  n_iter=12
# time= 392.6ms;  solution_found=true;  gs_error=0.000003919436848177769;  n_iter=12
# time= 212.0ms;  solution_found=true;  gs_error=0.000003908607781418561;  n_iter=12
# time= 745.0ms;  solution_found=true;  gs_error=0.000003957049031847124;  n_iter=12
# time= 785.1ms;  solution_found=true;  gs_error=0.000004015608315844599;  n_iter=12
# time= 527.2ms;  solution_found=true;  gs_error=0.0000040378615242641605;  n_iter=12
# time= 366.8ms;  solution_found=true;  gs_error=0.0000040825862692507215;  n_iter=12
# time= 269.3ms;  solution_found=true;  gs_error=0.000004153709897687363;  n_iter=12
# time= 214.9ms;  solution_found=true;  gs_error=0.000004010981502763236;  n_iter=12
# time= 770.8ms;  solution_found=true;  gs_error=0.0000035814542128904013;  n_iter=12
# time= 616.0ms;  solution_found=true;  gs_error=0.0000034457873033432596;  n_iter=12
# time= 939.8ms;  solution_found=true;  gs_error=0.0000036553458976566694;  n_iter=12
# time= 862.5ms;  solution_found=true;  gs_error=0.000004043376554587645;  n_iter=12
# time= 650.4ms;  solution_found=true;  gs_error=0.000003911861785109981;  n_iter=12
# time= 853.9ms;  solution_found=true;  gs_error=0.000003923463211481828;  n_iter=12
# time= 275.1ms;  solution_found=true;  gs_error=0.000004177692333965813;  n_iter=12
# time= 341.0ms;  solution_found=true;  gs_error=0.0000037653859890564406;  n_iter=12
# time= 363.9ms;  solution_found=true;  gs_error=0.000003848570324884716;  n_iter=12
# time= 369.6ms;  solution_found=true;  gs_error=0.000003927920337584964;  n_iter=12
# time= 406.9ms;  solution_found=true;  gs_error=0.000004082944946388415;  n_iter=12
# time= 776.5ms;  solution_found=true;  gs_error=0.000004381935468916567;  n_iter=12
# time= 819.5ms;  solution_found=true;  gs_error=0.0000008111335277686342;  n_iter=8
# time= 277.9ms;  solution_found=true;  gs_error=0.0000032902320046071578;  n_iter=9
# time= 303.7ms;  solution_found=true;  gs_error=0.000004327075699716808;  n_iter=12
# time= 885.4ms;  solution_found=true;  gs_error=0.000004020143930455252;  n_iter=12
# time=  80.2ms;  solution_found=true;  gs_error=0.000003832414110020629;  n_iter=12
# time= 653.3ms;  solution_found=true;  gs_error=0.000003914002944180503;  n_iter=12
# time= 355.3ms;  solution_found=true;  gs_error=0.000004217191702156045;  n_iter=12
# time= 441.3ms;  solution_found=true;  gs_error=0.000003387119326245964;  n_iter=12
# time= 398.3ms;  solution_found=true;  gs_error=0.000004223798924675626;  n_iter=12
# time= 300.9ms;  solution_found=true;  gs_error=0.000003766611917761516;  n_iter=12
# time= 618.9ms;  solution_found=true;  gs_error=0.0000006838396126861749;  n_iter=8
# time= 395.4ms;  solution_found=true;  gs_error=0.000003926699497474832;  n_iter=12
# time= 372.5ms;  solution_found=true;  gs_error=0.000003527064451801265;  n_iter=12
# time= 856.7ms;  solution_found=true;  gs_error=0.0000040774079974490725;  n_iter=12
# time= 796.6ms;  solution_found=true;  gs_error=0.000003867364697583578;  n_iter=12
# time= 747.9ms;  solution_found=true;  gs_error=0.000003873185165612265;  n_iter=12
# time= 922.6ms;  solution_found=true;  gs_error=0.000000988138901852735;  n_iter=9
# time= 779.4ms;  solution_found=true;  gs_error=0.0000032327559483129135;  n_iter=9
# time= 788.0ms;  solution_found=true;  gs_error=0.000003943192903611087;  n_iter=12
# time= 790.8ms;  solution_found=true;  gs_error=0.000004006275245206285;  n_iter=12
# time= 828.1ms;  solution_found=true;  gs_error=0.000003842889300345361;  n_iter=12
# time= 793.7ms;  solution_found=true;  gs_error=0.000004362422356624185;  n_iter=12
# time= 865.3ms;  solution_found=true;  gs_error=0.000003855060708473737;  n_iter=12
# time= 306.6ms;  solution_found=true;  gs_error=0.000004004295729959343;  n_iter=12
# time= 942.7ms;  solution_found=true;  gs_error=0.0000040667055475205656;  n_iter=12
# time=  83.1ms;  solution_found=true;  gs_error=0.000003856376498342354;  n_iter=12
# time= 908.3ms;  solution_found=true;  gs_error=0.000003718116513464093;  n_iter=12
# time= 805.2ms;  solution_found=true;  gs_error=0.000003916591961724605;  n_iter=12
# time=  91.7ms;  solution_found=true;  gs_error=0.0000042357469203819855;  n_iter=12
# time= 621.8ms;  solution_found=true;  gs_error=0.000003985284631864579;  n_iter=12
# time= 822.3ms;  solution_found=true;  gs_error=0.000004498152283126223;  n_iter=12
# time= 409.7ms;  solution_found=true;  gs_error=0.000004373620858538038;  n_iter=12
# time= 825.2ms;  solution_found=true;  gs_error=0.00000382016670645676;  n_iter=12
# time= 931.2ms;  solution_found=true;  gs_error=0.000004081698553872461;  n_iter=12
# time= 925.5ms;  solution_found=true;  gs_error=0.000003848404643926862;  n_iter=12
# time= 888.3ms;  solution_found=true;  gs_error=0.0000037383321623507405;  n_iter=12
# time= 868.2ms;  solution_found=true;  gs_error=0.0000033504983356387356;  n_iter=9
# time= 836.7ms;  solution_found=true;  gs_error=0.000003977649852314181;  n_iter=12
# time= 421.2ms;  solution_found=true;  gs_error=0.000004007441784390763;  n_iter=12
# time= 444.1ms;  solution_found=true;  gs_error=0.000003808680970862374;  n_iter=12
# time= 839.5ms;  solution_found=true;  gs_error=0.000004218999268170409;  n_iter=12
# time= 401.1ms;  solution_found=true;  gs_error=0.0000038716559910683546;  n_iter=12
# time= 309.5ms;  solution_found=true;  gs_error=0.000003992333345221276;  n_iter=12
# time=  86.0ms;  solution_found=true;  gs_error=0.00000414291433893651;  n_iter=12
# time= 971.3ms;  solution_found=true;  gs_error=0.000003919822875639365;  n_iter=12
# time= 404.0ms;  solution_found=true;  gs_error=0.000004234331272719693;  n_iter=12
# time= 799.4ms;  solution_found=true;  gs_error=0.000003944739773492757;  n_iter=12
# time= 891.1ms;  solution_found=true;  gs_error=0.000003870783258713623;  n_iter=12
# time= 928.4ms;  solution_found=true;  gs_error=0.000003939472242709379;  n_iter=12
# time= 106.0ms;  solution_found=true;  gs_error=0.000003926501461641131;  n_iter=12
# time= 954.2ms;  solution_found=true;  gs_error=0.0000037939823928509455;  n_iter=12
# time= 871.1ms;  solution_found=true;  gs_error=0.000004137713357334417;  n_iter=12
# time= 429.8ms;  solution_found=true;  gs_error=0.000004094880209610268;  n_iter=12
# time= 830.9ms;  solution_found=true;  gs_error=0.000004218610554685879;  n_iter=12
# time= 802.3ms;  solution_found=true;  gs_error=0.000003827052430004198;  n_iter=12
# time= 945.6ms;  solution_found=true;  gs_error=0.00000405980195405453;  n_iter=12
# time= 899.7ms;  solution_found=true;  gs_error=0.0000036936808055968982;  n_iter=12
# time= 911.2ms;  solution_found=true;  gs_error=0.000004091769786496262;  n_iter=12
# time= 808.0ms;  solution_found=true;  gs_error=0.000004350949768837492;  n_iter=12
# time= 873.9ms;  solution_found=true;  gs_error=0.000003836158554920015;  n_iter=12
# time=  94.6ms;  solution_found=true;  gs_error=0.000004156555093512321;  n_iter=12
# time= 412.6ms;  solution_found=true;  gs_error=0.000003956127427798637;  n_iter=12
# time= 894.0ms;  solution_found=true;  gs_error=0.000003966842609638792;  n_iter=12
# time= 934.1ms;  solution_found=true;  gs_error=0.0000038883872841896455;  n_iter=12
# time= 432.7ms;  solution_found=true;  gs_error=0.0000040437712410056975;  n_iter=12
# time= 948.4ms;  solution_found=true;  gs_error=0.000003880424172577178;  n_iter=12
# time= 842.4ms;  solution_found=true;  gs_error=0.000004263822020283965;  n_iter=12
# time= 415.5ms;  solution_found=true;  gs_error=0.0000040070942398178096;  n_iter=12
# time=  88.8ms;  solution_found=true;  gs_error=0.00000003867885335037095;  n_iter=10
# time= 937.0ms;  solution_found=true;  gs_error=0.000004024759940685072;  n_iter=12
# time=  97.4ms;  solution_found=true;  gs_error=0.000004276806220422622;  n_iter=12
# time= 424.1ms;  solution_found=true;  gs_error=0.000004024205185375913;  n_iter=12
# time= 447.0ms;  solution_found=true;  gs_error=0.000003711689514209607;  n_iter=12
# time= 951.3ms;  solution_found=true;  gs_error=0.000004170200792689026;  n_iter=12
# time= 962.8ms;  solution_found=true;  gs_error=0.000004063003784026398;  n_iter=12
# time= 896.8ms;  solution_found=true;  gs_error=0.000003791503346563392;  n_iter=12
# time= 974.2ms;  solution_found=true;  gs_error=0.000004464396926715073;  n_iter=12
# time= 965.6ms;  solution_found=true;  gs_error=0.0000036686141518238506;  n_iter=12
# time= 435.5ms;  solution_found=true;  gs_error=0.000003912028559124205;  n_iter=12
# time= 968.5ms;  solution_found=true;  gs_error=0.000003797255171890747;  n_iter=12
# time= 914.0ms;  solution_found=true;  gs_error=0.000003913315697957679;  n_iter=12
# time= 108.9ms;  solution_found=true;  gs_error=0.00000437197346214785;  n_iter=12
# time= 492.8ms;  solution_found=true;  gs_error=0.000004563589381783108;  n_iter=9
# time= 985.7ms;  solution_found=true;  gs_error=0.000003831284300041948;  n_iter=12
# time= 902.6ms;  solution_found=true;  gs_error=0.000003779004610994332;  n_iter=12
# time= 957.0ms;  solution_found=true;  gs_error=0.000003992151675523064;  n_iter=12
# time= 977.1ms;  solution_found=true;  gs_error=0.000004328104245141594;  n_iter=12
# time= 449.9ms;  solution_found=true;  gs_error=0.000003216235682746202;  n_iter=9
# time= 810.9ms;  solution_found=true;  gs_error=0.000003935713805199092;  n_iter=12
# time= 833.8ms;  solution_found=true;  gs_error=0.000004476114144821257;  n_iter=12
# time= 959.9ms;  solution_found=true;  gs_error=0.000003621931910777125;  n_iter=12
# time= 469.9ms;  solution_found=true;  gs_error=0.0000040529065796645685;  n_iter=12
# time= 475.6ms;  solution_found=true;  gs_error=0.00000398604101017229;  n_iter=12
# time= 484.2ms;  solution_found=true;  gs_error=0.0000039195543670623025;  n_iter=12
# time= 916.9ms;  solution_found=true;  gs_error=0.0000041704839344570815;  n_iter=12
# time= 994.3ms;  solution_found=true;  gs_error=0.000003960710779042782;  n_iter=12
# time= 472.8ms;  solution_found=true;  gs_error=0.000003584539057224401;  n_iter=12
# time= 495.7ms;  solution_found=true;  gs_error=0.0000006932696893904838;  n_iter=9
# time= 452.7ms;  solution_found=true;  gs_error=0.000003924530906805785;  n_iter=12
# time= 979.9ms;  solution_found=true;  gs_error=0.000003828640224196345;  n_iter=12
# time= 988.5ms;  solution_found=true;  gs_error=0.000004117446215587009;  n_iter=9
# time= 418.3ms;  solution_found=true;  gs_error=0.000004498817308902409;  n_iter=12
# time= 982.8ms;  solution_found=true;  gs_error=0.000004083074786212813;  n_iter=12
# time= 100.3ms;  solution_found=true;  gs_error=0.000004067985368349274;  n_iter=12
# time= 498.6ms;  solution_found=true;  gs_error=0.00000405416558088558;  n_iter=12
# time= 905.4ms;  solution_found=true;  gs_error=0.0000036813330903443013;  n_iter=12
# time= 426.9ms;  solution_found=true;  gs_error=0.000004014265105754069;  n_iter=12
# time= 997.1ms;  solution_found=true;  gs_error=0.00000389986955870013;  n_iter=12
# time= 461.3ms;  solution_found=true;  gs_error=0.0000040046450045622435;  n_iter=12
# time=1000.0ms;  solution_found=true;  gs_error=0.0000033162855920618564;  n_iter=9
# time= 111.7ms;  solution_found=true;  gs_error=0.000004323451939513761;  n_iter=12
# time= 478.5ms;  solution_found=true;  gs_error=0.000003948939507775462;  n_iter=12
# time= 464.2ms;  solution_found=true;  gs_error=0.000003742956004997954;  n_iter=12
# time= 919.8ms;  solution_found=true;  gs_error=0.000004310119110817645;  n_iter=12
# time= 991.4ms;  solution_found=true;  gs_error=0.0000041059676717963544;  n_iter=12
# time= 458.5ms;  solution_found=true;  gs_error=0.000004220272407621021;  n_iter=12
# time= 481.4ms;  solution_found=true;  gs_error=0.000004316636486851733;  n_iter=12
# time= 455.6ms;  solution_found=true;  gs_error=0.00000402350717936201;  n_iter=12
# time= 487.1ms;  solution_found=true;  gs_error=0.0000041606456726442;  n_iter=12
# time= 467.0ms;  solution_found=true;  gs_error=0.000003982646755290583;  n_iter=12
# time= 114.6ms;  solution_found=true;  gs_error=0.000003950651862525752;  n_iter=12
# time= 117.5ms;  solution_found=true;  gs_error=0.00000387365222979585;  n_iter=12
# time= 490.0ms;  solution_found=true;  gs_error=0.00000396947684769971;  n_iter=12
# time= 103.2ms;  solution_found=true;  gs_error=0.000004145373521128762;  n_iter=12
# time= 120.3ms;  solution_found=true;  gs_error=0.000004036201059079345;  n_iter=12
# equilibrium_post_processor: starting
# 2026-04-08 09:47:46  |  GSFIT  |  gsfit.py:130                           |  INFO  |  pulseNo = None pulseNo_write = None run_name = TEST_01

# %%
def plot_equilibrium(gsfit_controller, plot_color="red", ax=None):
    # Create a figure and axes if not provided
    if ax is None:
        _fig, ax = plt.subplots(2, 3, figsize=(20, 12), dpi=110)

    plasma = gsfit_controller.plasma

    for i_x in [0, 1, 2]:
        ax[0, i_x].set_aspect("equal")
        for i_time in range(1, int(n_random_scans / 2.0)):  # 0th time-slice is without noise
            gsfit_rbnd = plasma.get_array2(["p_boundary", "rbnd"])[i_time, :]
            gsfit_zbnd = plasma.get_array2(["p_boundary", "zbnd"])[i_time, :]
            ax[0, i_x].plot(gsfit_rbnd * 100.0, gsfit_zbnd * 100.0, color=plot_color, linewidth=0.25)
        ax[0, i_x].plot(gsfit_no_noise_rbnd * 100.0, gsfit_no_noise_zbnd * 100.0, color="black", linewidth=0.75)
        ax[0, i_x].plot(r_limit_pts * 100.0, z_limit_pts * 100.0, color="black", linewidth=0.5)
        ax[0, i_x].set_xlabel("R [cm]")
        ax[0, i_x].set_ylabel("Z [cm]")

    ax[0, 1].set_xlim(15.0, 55.0)
    ax[0, 1].set_ylim(-60.0, -35.0)

    ax[0, 2].set_xlim(15.0, 55.0)
    ax[0, 2].set_ylim(35.0, 60.0)

    r_geo_no_noise = plasma.get_array1(["global", "r_geo"])[0]
    z_geo_no_noise = plasma.get_array1(["global", "z_geo"])[0]

    # Go around the boundary and find the intersections
    n_theta = 400  # perhaps higher??
    thetas = np.linspace(0.0, 2.0 * np.pi, n_theta)

    # Loop over the last closed flux surface
    one_sigma_inner_r = np.full(n_theta, np.nan)
    one_sigma_inner_z = np.full(n_theta, np.nan)
    one_sigma_outer_r = np.full(n_theta, np.nan)
    one_sigma_outer_z = np.full(n_theta, np.nan)
    ci95_inner_r = np.full(n_theta, np.nan)
    ci95_inner_z = np.full(n_theta, np.nan)
    ci95_outer_r = np.full(n_theta, np.nan)
    ci95_outer_z = np.full(n_theta, np.nan)
    for i_theta in range(0, n_theta):
        theta = thetas[i_theta]

        normal_distribution_r = np.full(n_random_scans - 1, np.nan)  # first time-slice is without noise
        normal_distribution_z = np.full(n_random_scans - 1, np.nan)
        #
        for i_time in range(1, n_random_scans):  # 0th time-slice is without noise
            gsfit_nbnd = plasma.get_vec_usize(["p_boundary", "nbnd"])[i_time]
            gsfit_rbnd = plasma.get_array2(["p_boundary", "rbnd"])[i_time, 0:gsfit_nbnd]
            gsfit_zbnd = plasma.get_array2(["p_boundary", "zbnd"])[i_time, 0:gsfit_nbnd]
            x = np.sum(gsfit_rbnd)
            if np.isnan(x) or np.isinf(x):
                # raise ValueError("NaN or Inf found in gsfit_rbnd or gsfit_zbnd at time index {}".format(i_time))
                print(f"problem with i_time={i_time}")
                continue

            # From the geometric center of the plasma
            r_ray = np.array([r_geo_no_noise, r_geo_no_noise + 1.0 * np.cos(theta)])
            z_ray = np.array([z_geo_no_noise, z_geo_no_noise + 1.0 * np.sin(theta)])

            # Interpolate the boundary to find the intersection (should only be one intersection)
            boundary = LineString(np.column_stack((gsfit_rbnd, gsfit_zbnd)))
            ray = LineString(np.column_stack((r_ray, z_ray)))
            intersection = boundary.intersection(ray)
            if intersection.is_empty:
                # raise ValueError("No intersection found for theta={:.2f} at time index {}".format(theta, i_time))
                print(f"problem with i_time={i_time}")
                continue

            if isinstance(intersection, Point):
                normal_distribution_r[i_time - 1] = intersection.x
                normal_distribution_z[i_time - 1] = intersection.y
            else:
                # raise ValueError(f"Unexpected intersection type: {type(intersection)}; time={i_time}")
                print(f"problem with i_time={i_time}")
                continue

        # Fit a normal distribution
        normal_distribution_r_mean = np.mean(normal_distribution_r)
        normal_distribution_r_sigma = np.std(normal_distribution_r)
        one_sigma_inner_r[i_theta] = normal_distribution_r_mean - normal_distribution_r_sigma
        one_sigma_outer_r[i_theta] = normal_distribution_r_mean + normal_distribution_r_sigma
        # 95% confidence interval (mean ± 1.96 * std)
        ci95_inner_r[i_theta] = normal_distribution_r_mean - 1.96 * normal_distribution_r_sigma
        ci95_outer_r[i_theta] = normal_distribution_r_mean + 1.96 * normal_distribution_r_sigma

        # Fit a normal distribution to z
        normal_distribution_z_mean = np.mean(normal_distribution_z)
        normal_distribution_z_sigma = np.std(normal_distribution_z)
        one_sigma_inner_z[i_theta] = normal_distribution_z_mean - normal_distribution_z_sigma
        one_sigma_outer_z[i_theta] = normal_distribution_z_mean + normal_distribution_z_sigma
        # 95% confidence interval (mean ± 1.96 * std)
        ci95_inner_z[i_theta] = normal_distribution_z_mean - 1.96 * normal_distribution_z_sigma
        ci95_outer_z[i_theta] = normal_distribution_z_mean + 1.96 * normal_distribution_z_sigma

    # Plot results
    for i_x in [0, 1, 2]:
        ax[1, i_x].set_aspect("equal")

        ax[1, i_x].plot(r_limit_pts * 100.0, z_limit_pts * 100.0, color="black", linewidth=0.5)

        ax[1, i_x].fill(
            np.concatenate([ci95_inner_r, np.flip(ci95_outer_r)]) * 100.0,
            np.concatenate([ci95_inner_z, np.flip(ci95_outer_z)]) * 100.0,
            color=plot_color,
            alpha=0.3,
            linestyle="none",
            label="±1 Std Dev",
        )
        ax[1, i_x].fill(
            np.concatenate([one_sigma_inner_r, np.flip(one_sigma_outer_r)]) * 100.0,
            np.concatenate([one_sigma_inner_z, np.flip(one_sigma_outer_z)]) * 100.0,
            color=plot_color,
            linestyle="none",
            # alpha=0.8,
            label="±1 Std Dev",
        )
        ax[1, i_x].plot(gsfit_no_noise_rbnd * 100.0, gsfit_no_noise_zbnd * 100.0, color="black", linewidth=0.75)

        ax[1, 1].set_xlim(15.0, 55.0)
        ax[1, 1].set_ylim(-60.0, -35.0)

        ax[1, 2].set_xlim(15.0, 55.0)
        ax[1, 2].set_ylim(35.0, 60.0)

        ax[1, i_x].set_xlabel("R [cm]")
        ax[1, i_x].set_ylabel("Z [cm]")


plot_equilibrium(gsfit_controller)

# %%
plot_magnetic_probes(gsfit_controller)

# %%
gsfit_controller_w_new_sensors = Gsfit(
    pulseNo=None,
    run_name="test_01",
    run_description="using FreeGS to generate measurements",
    settings_path="st40_all_magnetic_sensors_working",
    write_to_mds=False,
)
gsfit_controller_w_new_sensors.settings["GSFIT_code_settings.json"]["database_reader"]["method"] = "freegs"
gsfit_controller_w_new_sensors.settings["GSFIT_code_settings.json"]["timeslices"]["method"] = "user_defined"
gsfit_controller_w_new_sensors.settings["GSFIT_code_settings.json"]["numerics"]["gs_error"] = 2.0e-5

new_sensors = {
    "P135": {
        "r": 0.30001,
        "z": -0.700001,
        "angle": np.pi + np.pi / 8.0,
    }
}

# Add the new sensors
freegs_sensors_with_new = copy.deepcopy(freegs_eq.tokamak.sensors)
for sensor_name in new_sensors.keys():
    # Add the new sensor
    sensor_name_full = f"{sensor_name}_BOTTOM"
    freegs_sensor = freegs.machine.PoloidalFieldSensor(
        R=new_sensors[sensor_name]["r"],
        Z=-new_sensors[sensor_name]["z"],
        theta=new_sensors[sensor_name]["angle"],
        name=sensor_name_full,
    )
    freegs_sensors_with_new.append(freegs_sensor)
    new_sensor_settings = {
        "fit_settings": {
            "expected_value": 0.01,
            "weight": 10.0,
            "include": True,  # Include the new sensor in the fit
            "comment": "new sensor",
        }
    }
    gsfit_controller_w_new_sensors.settings["sensor_weights_bp_probe.json"][sensor_name_full] = new_sensor_settings

    # Add the corresponding sensor to the top
    sensor_name_full = f"{sensor_name}_TOP"
    freegs_sensor = freegs.machine.PoloidalFieldSensor(
        R=new_sensors[sensor_name]["r"],
        Z=-new_sensors[sensor_name]["z"],
        theta=new_sensors[sensor_name]["angle"] + 2.0 * np.pi,
        name=sensor_name_full,
    )
    freegs_sensors_with_new.append(freegs_sensor)
    gsfit_controller_w_new_sensors.settings["sensor_weights_bp_probe.json"][sensor_name_full] = new_sensor_settings

# Add the new sensors to the FreeGS object
freegs_eq_with_new_sensors = copy.deepcopy(freegs_eq)
freegs_eq_with_new_sensors.tokamak.sensors = freegs_sensors_with_new
freegs_eq_with_new_sensors.tokamak.takeMeasurements(eq=freegs_eq_with_new_sensors)

# Add random noise to the positions of the magnetic sensors
freegs_eqs_with_random_noise = []
freegs_eqs_with_random_noise.append(freegs_eq_with_new_sensors)  # The original equilibrium is first
for i_random_scan in range(1, n_random_scans):
    freegs_eq_with_random_noise = copy.deepcopy(freegs_eq_with_new_sensors)
    # Use the rng Generator for deterministic random noise
    for i_sensor, sensor in enumerate(freegs_eq_with_new_sensors.tokamak.sensors):
        # measurement = sensor.measurement
        r_sensor = sensor.R
        z_sensor = sensor.Z

        # Add random normal noise to the sensor positions
        freegs_eq_with_random_noise.tokamak.sensors[i_sensor].R = rng.normal(r_sensor, 2e-3)
        freegs_eq_with_random_noise.tokamak.sensors[i_sensor].Z = rng.normal(z_sensor, 2e-3)

        try:
            angle_no_noise = sensor.theta
            freegs_eq_with_random_noise.tokamak.sensors[i_sensor].theta = rng.normal(angle_no_noise, np.deg2rad(2.5))
        except:
            pass

    # Take measurements
    freegs_eq_with_random_noise.tokamak.takeMeasurements(eq=freegs_eq_with_random_noise)

    # Append the modified equilibrium to the list to be reconstructed
    freegs_eqs_with_random_noise.append(freegs_eq_with_random_noise)

time = np.linspace(0.0, 1.0, n_random_scans)

gsfit_controller_w_new_sensors.settings["GSFIT_code_settings.json"]["timeslices"]["user_defined"] = time.tolist()

# Solve with random noise
gsfit_controller_w_new_sensors.run(time=time, freegs_eqs=freegs_eqs_with_random_noise)
# Out:
# 2026-04-08 09:48:28  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "GSFIT_code_settings.json"
# 2026-04-08 09:48:28  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "passive_dof_regularisation.json"
# 2026-04-08 09:48:28  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "sensor_weights_bp_probe.json"
# 2026-04-08 09:48:28  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "sensor_weights_dialoop.json"
# 2026-04-08 09:48:28  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "sensor_weights_flux_loops.json"
# 2026-04-08 09:48:28  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "sensor_weights_isoflux.json"
# 2026-04-08 09:48:28  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "sensor_weights_pressure.json"
# 2026-04-08 09:48:28  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "sensor_weights_rogowski_coils.json"
# 2026-04-08 09:48:28  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "source_function_ff_prime.json"
# 2026-04-08 09:48:28  |  GSFIT  |  diagnostic_and_simulation_base.py:159  |  INFO  |  Loading settings from: "source_function_p_prime.json"
# 2026-04-08 09:51:36  |  GSFIT  |  gsfit.py:92                            |  INFO  |  Running Gsfit, for pulseNo=None
# 2026-04-08 09:51:36  |  GSFIT  |  gsfit.py:290                           |  INFO  |  `coils`  initialised;  0.29ms
# 2026-04-08 09:51:36  |  GSFIT  |  gsfit.py:295                           |  INFO  |  `bp_probes` initialised;  7.57ms
# 2026-04-08 09:51:36  |  GSFIT  |  gsfit.py:300                           |  INFO  |  `flux_loops` initialised;  6.72ms
# 2026-04-08 09:51:36  |  GSFIT  |  gsfit.py:305                           |  INFO  |  `rogowski_coils` initialised;  0.25ms
# 2026-04-08 09:51:36  |  GSFIT  |  gsfit.py:310                           |  INFO  |  `passives` initialised;  0.03ms
# 2026-04-08 09:51:37  |  GSFIT  |  gsfit.py:315                           |  INFO  |  `plasma` initialised;  616.50ms
# 2026-04-08 09:51:37  |  GSFIT  |  gsfit.py:321                           |  INFO  |  `isoflux` initialised;  0.03ms
# 2026-04-08 09:51:37  |  GSFIT  |  gsfit.py:326                           |  INFO  |  `isoflux_boundary` initialised;  0.01ms
# 2026-04-08 09:51:37  |  GSFIT  |  gsfit.py:331                           |  INFO  |  `pressure_sensors` initialised;  0.02ms
# 2026-04-08 09:51:37  |  GSFIT  |  gsfit.py:341                           |  INFO  |  `stationary_point` initialised;  0.02ms
# 2026-04-08 09:51:40  |  GSFIT  |  gsfit.py:243                           |  INFO  |  Finished Greens with coils;  2,871.37ms
# 2026-04-08 09:51:40  |  GSFIT  |  gsfit.py:256                           |  INFO  |  Finished Greens with passives;  0.31ms
# 2026-04-08 09:51:40  |  GSFIT  |  gsfit.py:268                           |  INFO  |  Finished Greens with plasma;  263.67ms
# 2026-04-08 09:51:40  |  GSFIT  |  gsfit.py:190                           |  INFO  |  About to call: `gsfit_rs.solve_grad_shafranov`

# %%
plot_magnetic_probes(gsfit_controller_w_new_sensors)

# %%
_fig, ax = plt.subplots(2, 3, figsize=(20, 12), dpi=110)
plot_equilibrium(gsfit_controller, ax=ax)
plot_equilibrium(gsfit_controller_w_new_sensors, plot_color="blue", ax=ax)

# %%
# Test tensioned b-splines
gsfit_controller_spline_p_prime = Gsfit(
    pulseNo=None,
    run_name="test_01",
    run_description="using FreeGS to generate measurements",
    settings_path="st40_all_magnetic_sensors_working",
    write_to_mds=False,
)
gsfit_controller_spline_p_prime.settings["GSFIT_code_settings.json"]["database_reader"]["method"] = "freegs"
gsfit_controller_spline_p_prime.settings["GSFIT_code_settings.json"]["timeslices"]["method"] = "user_defined"
gsfit_controller_spline_p_prime.settings["GSFIT_code_settings.json"]["timeslices"]["user_defined"] = [0.5]
gsfit_controller_spline_p_prime.settings["source_function_p_prime.json"]["method"] = "tensioned_cubic_b_spline"
gsfit_controller_spline_p_prime.settings["GSFIT_code_settings.json"]["numerics"]["gs_error"] = 1.0e-2

gsfit_controller_spline_p_prime.run(time=np.array([0.0, 1.0]), freegs_eqs=[freegs_eq, freegs_eq])

# %%
spline_p_prime = gsfit_controller_spline_p_prime.plasma.get_array2(["profiles", "p_prime"])[0, :]

# %%
psi_n = gsfit_controller.plasma.get_array1(["profiles", "psi_n"])
p_prime = gsfit_controller.plasma.get_array2(["profiles", "p_prime"])[0, :]
ff_prime = gsfit_controller.plasma.get_array2(["profiles", "ff_prime"])[0, :]

freegs_p_prime = freegs_eq.pprime(psi_n)
freegs_ff_prime = freegs_eq.ffprime(psi_n)

plt.figure()
plt.plot(psi_n, freegs_p_prime / (2.0 * np.pi), label="FreeGS p'")
plt.plot(psi_n, p_prime, label="GSFit p'")
plt.plot(psi_n, spline_p_prime, label="GSFit p' with tensioned b-spline")
plt.legend()

plt.figure()
plt.plot(psi_n, freegs_ff_prime / (2.0 * np.pi), label="FreeGS ff'")
plt.plot(psi_n, ff_prime, label="GSFit ff'")
plt.plot(psi_n, spline_p_prime, label="GSFit ff' with tensioned b-spline")

# %%
freegs_r = freegs_eq.R
freegs_z = freegs_eq.Z
freegs_r_1d = freegs_eq.R_1D
freegs_z_1d = freegs_eq.Z_1D
freegs_psi = freegs_eq.psiRZ(freegs_r, freegs_z).T * (2.0 * np.pi)  # Convert from Wb/(2*pi) to Wb
freegs_psi_b = freegs_eq.psi_bndry * (2.0 * np.pi)

# Note: we will plot with the same `psi_range` for FreeGS and GSFit
psi_range = np.linspace(np.min(freegs_psi), np.max(freegs_psi), 30)

i_time = 0  # only one time-slice

# GSFit (baseline)
gsfit_psi = gsfit_controller["TWO_D"]["PSI"][i_time, :, :]
gsfir_r = gsfit_controller.plasma.get_array1(["grid", "r"])
gsfit_z = gsfit_controller.plasma.get_array1(["grid", "z"])
gsfit_no_noise_rbnd = gsfit_controller.plasma.get_array2(["p_boundary", "rbnd"])[i_time, :]
gsfit_no_noise_zbnd = gsfit_controller.plasma.get_array2(["p_boundary", "zbnd"])[i_time, :]
bounding_r = gsfit_controller.plasma.get_array1(["p_boundary", "bounding_r"])
bounding_z = gsfit_controller.plasma.get_array1(["p_boundary", "bounding_z"])

# GSFit (tensioned cubic b-spline p')
spline_psi = gsfit_controller_spline_p_prime["TWO_D"]["PSI"][i_time, :, :]
spline_r = gsfit_controller_spline_p_prime.plasma.get_array1(["grid", "r"])
spline_z = gsfit_controller_spline_p_prime.plasma.get_array1(["grid", "z"])
spline_rbnd = gsfit_controller_spline_p_prime.plasma.get_array2(["p_boundary", "rbnd"])[i_time, :]
spline_zbnd = gsfit_controller_spline_p_prime.plasma.get_array2(["p_boundary", "zbnd"])[i_time, :]

plt.figure()
plt.plot(r_limit_pts, z_limit_pts, color="black", linewidth=0.5)

# FreeGS
plt.contour(freegs_r_1d, freegs_z_1d, freegs_psi, levels=psi_range, colors="blue", linewidths=0.25, linestyles="solid")
plt.contour(freegs_r_1d, freegs_z_1d, freegs_psi, [freegs_psi_b], colors="blue", linewidths=0.75, linestyles="solid")

# GSFit baseline
plt.contour(gsfir_r, gsfit_z, gsfit_psi, levels=psi_range, colors="red", linewidths=0.25, linestyles="dashed")
plt.plot(gsfit_no_noise_rbnd, gsfit_no_noise_zbnd, color="red", linewidth=0.75, linestyle="dashed", label="GSFit")
plt.plot(bounding_r[i_time], bounding_z[i_time], "s", color="red")

# GSFit spline
plt.contour(spline_r, spline_z, spline_psi, levels=psi_range, colors="green", linewidths=0.25, linestyles="dashdot")
plt.plot(spline_rbnd, spline_zbnd, color="green", linewidth=0.75, linestyle="dashdot", label="GSFit (spline p')")

plt.gca().set_aspect("equal")
plt.legend()
